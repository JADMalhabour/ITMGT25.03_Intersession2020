# %% [markdown]
# ## Web Scraping

# %% [markdown]
# Wikipedia:
#
# In web development, "tag soup" is a pejorative term that refers to syntactically or structurally incorrect HTML written for a web page. Because web browsers have historically treated HTML syntax or structural errors leniently, there has been little pressure for web developers to follow published standards, and therefore there is a need for all browser implementations to provide mechanisms to cope with the appearance of "tag soup", accepting and correcting for invalid syntax and structure where possible.

# %% [markdown]
# [BeautifulSoup4](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree. It commonly saves programmers hours or days of work.

# %% [markdown]
# ### Warmup

# %%
# Taken from the BeautifulSoup website

html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
# prettify

from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')

print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
# Get tags or document attributes:
# title
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
# What is the data type?
type(soup.title)
# Out:
# bs4.element.Tag

# %%
# dump name of the tag or attribute
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# "The Dormouse's story"

# %% [markdown]
# #### Inspect html string above
#
# ```
# ...
# <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  ...
# ```
#
# Note that `<title>...</title>`'s parent is `<head>...</head>`

# %%
soup.title.parent.name
# Out:
# 'head'

# %% [markdown]
# #### Get the first instance of a tag
#
# ```
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
# ```
#
# **```<p class="title">```**
#
# ```
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
# ```

# %%
# example: first paragraph (p)
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.p['class']
# Out:
# ['title']

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
# Get/find all
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %% [markdown]
# ### Get data from an actual website

# %% [markdown]
# **Review: What is HTTP?**
#
# HTTP (or Hypertext Transfer Protocol) is a protocol which allows the fetching of resources, such as HTML or JSON documents. It is the foundation of any data exchange on the Web and it is a client-server protocol, which means requests are initiated by the recipient, usually the Web browser. A complete document is reconstructed from the different sub-documents fetched, for instance text, layout description, images, videos, scripts, and more.
#
# Source: [An Overview of HTTP (mozilla.org)](https://developer.mozilla.org/en-US/docs/Web/HTTP/Overview)
#
# **What is an Application Programming Interface (API)?**
#
# An application program interface (API) is a set of routines, protocols, and tools for building software applications. Basically, an API specifies how software components should interact. Additionally, APIs are used when programming graphical user interface (GUI) components.
#
# Source: [Webopedia](https://www.webopedia.com/TERM/A/API.html)
#
# #### Python Requests Module
#
# Requests is a simple HTTP library for Python. The full documentation is found [here](https://requests.readthedocs.io/en/master/), but for this test, we don't need to go through the whole thing.
#
# To use it, simply import it.

# %%
import requests

"http://www.ateneo.edu/ls/jgsom/qmit/faculty"
result = requests.get("http://www.ateneo.edu/ls/jgsom/qmit/faculty")

# %% [markdown]
# The call to requests.get(url) returns a **requests.models.Response** object. What you can see from above is the HTTP Response, and if everything is normal, the status code should be **200**.

# %%
# be sure to check the status (result.status_code)
result.status_code
# Out:
# 200

# %% [markdown]
# HTTP normally returns text which Python can then process as a string. The text body may be found in the Response's attribute **text**.

# %%
# get text
result.text
# Out:
# '<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN" "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">\n\n<!-- paulirish.com/2008/conditional-stylesheets-vs-css-hacks-answer-neither/ -->\n<!--[if lt IE 7]> <html class="no-js ie6 ie" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" version="XHTML+RDFa 1.0" dir="ltr" \n  xmlns:content="http://purl.org/rss/1.0/modules/content/"\n  xmlns:dc="http://purl.org/dc/terms/"\n  xmlns:foaf="http://xmlns.com/foaf/0.1/"\n  xmlns:og="http://ogp.me/ns#"\n  xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"\n  xmlns:sioc="http://rdfs.org/sioc/ns#"\n  xmlns:sioct="http://rdfs.org/sioc/types#"\n  xmlns:skos="http://www.w3.org/2004/02/skos/core#"\n  xmlns:xsd="http://www.w3.org/2001/XMLSchema#"\n  xmlns:fb="http://ogp.me/ns/fb#"\n  xmlns:article="http://ogp.me/ns/article#"\n  xmlns:book="http://ogp.me/ns/book#"\n  xmlns:profile="http://ogp.me/ns/profile#"\n  xmlns:video="http://ogp.me/ns/video#"> <![endif]-->\n<!--[if IE 7]>    <html class="no-js ie7 ie" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" version="XHTML+RDFa 1.0" dir="ltr" \n  xmlns:content="http://purl.org/rss/1.0/modules/content/"\n  xmlns:dc="http://purl.org/dc/terms/"\n  xmlns:foaf="http://xmlns.com/foaf/0.1/"\n  xmlns:og="http://ogp.me/ns#"\n  xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"\n  xmlns:sioc="http://rdfs.org/sioc/ns#"\n  xmlns:sioct="http://rdfs.org/sioc/types#"\n  xmlns:skos="http://www.w3.org/2004/02/skos/core#"\n  xmlns:xsd="http://www.w3.org/2001/XMLSchema#"\n  xmlns:fb="http://ogp.me/ns/fb#"\n  xmlns:article="http://ogp.me/ns/article#"\n  xmlns:book="http://ogp.me/ns/book#"\n  xmlns:profile="http://ogp.me/ns/profile#"\n  xmlns:video="http://ogp.me/ns/video#"> <![endif]-->\n<!--[if IE 8]>    <html class="no-js ie8 ie" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" version="XHTML+RDFa 1.0" dir="ltr" \n  xmlns:content="http://purl.org/rss/1.0/modules/content/"\n  xmlns:dc="http://purl.org/dc/terms/"\n  xmlns:foaf="http://xmlns.com/foaf/0.1/"\n  xmlns:og="http://ogp.me/ns#"\n  xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"\n  xmlns:sioc="http://rdfs.org/sioc/ns#"\n  xmlns:sioct="http://rdfs.org/sioc/types#"\n  xmlns:skos="http://www.w3.org/2004/02/skos/core#"\n  xmlns:xsd="http://www.w3.org/2001/XMLSchema#"\n  xmlns:fb="http://ogp.me/ns/fb#"\n  xmlns:article="http://ogp.me/ns/article#"\n  xmlns:book="http://ogp.me/ns/book#"\n  xmlns:profile="http://ogp.me/ns/profile#"\n  xmlns:video="http://ogp.me/ns/video#"> <![endif]-->\n<!--[if IE 9]>    <html class="no-js ie9 ie" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" version="XHTML+RDFa 1.0" dir="ltr" \n  xmlns:content="http://purl.org/rss/1.0/modules/content/"\n  xmlns:dc="http://purl.org/dc/terms/"\n  xmlns:foaf="http://xmlns.com/foaf/0.1/"\n  xmlns:og="http://ogp.me/ns#"\n  xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"\n  xmlns:sioc="http://rdfs.org/sioc/ns#"\n  xmlns:sioct="http://rdfs.org/sioc/types#"\n  xmlns:skos="http://www.w3.org/2004/02/skos/core#"\n  xmlns:xsd="http://www.w3.org/2001/XMLSchema#"\n  xmlns:fb="http://ogp.me/ns/fb#"\n  xmlns:article="http://ogp.me/ns/article#"\n  xmlns:book="http://ogp.me/ns/book#"\n  xmlns:profile="http://ogp.me/ns/profile#"\n  xmlns:video="http://ogp.me/ns/video#"> <![endif]-->\n<!--[if gt IE 9]><!--> <html class="no-js" xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" version="XHTML+RDFa 1.0" dir="ltr" \n  xmlns:content="http://purl.org/rss/1.0/modules/content/"\n  xmlns:dc="http://purl.org/dc/terms/"\n  xmlns:foaf="http://xmlns.com/foaf/0.1/"\n  xmlns:og="http://ogp.me/ns#"\n  xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"\n  xmlns:sioc="http://rdfs.org/sioc/ns#"\n  xmlns:sioct="http://rdfs.org/sioc/types#"\n  xmlns:skos="http://www.w3.org/2004/02/skos/core#"\n  xmlns:xsd="http://www.w3.org/2001/XMLSchema#"\n  xmlns:fb="http://ogp.me/ns/fb#"\n  xmlns:article="http://ogp.me/ns/article#"\n  xmlns:book="http://ogp.me/ns/book#"\n  xmlns:profile="http://ogp.me/ns/profile#"\n  xmlns:video="http:// ...

# %% [markdown]
# We already imported BeautifulSoup previously, so need to reimport. There's no harm in doing so again, however.

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(result.text)

# %%
soup.find_all("div")
# Out:
# [<div id="skip-link">
#  <a href="#main-content-area">Skip to main content area</a>
#  </div>, <div class="page" id="page">
#  <div class="page-inner" id="page-inner">
#  <!-- header-group region: width = grid_width -->
#  <div class="header-group-wrapper full-width clearfix" id="header-group-wrapper">
#  <div class="header-group region grid12-12" id="header-group">
#  <div class="header-group-inner inner clearfix" id="header-group-inner">
#  <div class="header-site-info clearfix" id="header-site-info">
#  <div class="header-site-info-inner gutter" id="header-site-info-inner">
#  <div id="logo">
#  <a href="/" title="Ateneo de Manila University Home"><img alt="Ateneo de Manila University Home" src="http://www.ateneo.edu/sites/default/files/masthead1_0.png"/></a>
#  </div>
#  </div><!-- /header-site-info-inner -->
#  </div><!-- /header-site-info -->
#  <div class="block block-superfish first odd" id="block-superfish-17">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="sf-menu menu-loyola-schools sf-horizontal sf-style-none sf-total-items-1 sf-parent-items-1 sf-single-items-0" id="superfish-17"><li class="first odd sf-item-1 sf-depth-1 sf-total-children-4 sf-parent-children-0 sf-single-children-4 menuparent" id="menu-2828-17"><span class="sf-depth-1 menuparent nolink">Loyola Schools</span><ul><li class="first odd sf-item-1 sf-depth-2 sf-no-children" id="menu-2750-17"><a class="sf-depth-2" href="/ls/jgsom">John Gokongwei School of Management</a></li><li class="middle even sf-item-2 sf-depth-2 sf-no-children" id="menu-2747-17"><a class="sf-depth-2" href="/ls/soh">School of Humanities</a></li><li class="middle odd sf-item-3 sf-depth-2 sf-no-children" id="menu-2749-17"><a class="sf-depth-2" href="/ls/sose">School of Science and Engineering</a></li><li class="last even sf-item-4 sf-depth-2 sf-no-children" id="menu-2748-17"><a class="sf-depth-2" href="/ls/soss">School of Social Sciences</a></li></ul></li></ul> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-superfish even" id="block-superfish-6">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="sf-menu menu-main-first sf-horizontal sf-style-none sf-total-items-2 sf-parent-items-0 sf-single-items-2" id="superfish-6"><li class="first odd sf-item-1 sf-depth-1 sf-no-children" id="menu-1956-6"><a class="sf-depth-1" href="/">About</a></li><li class="last even sf-item-2 sf-depth-1 sf-no-children" id="menu-1957-6"><a class="sf-depth-1" href="/index">Index</a></li></ul> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-custom-search-blocks last odd" id="block-custom_search_blocks-1">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <form accept-charset="UTF-8" action="/ls/jgsom/qmit/faculty" class="search-form" id="custom-search-blocks-form-1" method="post"><div><div class="form-item form-type-textfield form-item-custom-search-blocks-form-1">
#  <input class="custom-search-default-value custom-search-box form-text" id="edit-custom-search-blocks-form-1--2" maxlength="128" name="custom_search_blocks_form_1" size="15" type="text" value=""/>
#  </div>
#  <fieldset class="custom_search-popup form-wrapper" id="edit-popup"><div class="fieldset-wrapper"></div></fieldset>
#  <input name="delta" type="hidden" value="1"/>
#  <input name="form_build_id" type="hidden" value="form-MRozykvRg6iW_tkfwphn_ZTXwH8Jykk2LiVMT1hEM7s"/>
#  <input name="form_id" type="hidden" value="custom_search_blocks_form_1"/>
#  <input class="default-text" name="default_text" type="hidden" value=""/>
#  <div class="form-actions form-wrapper" id="edit-actions"><input class="form-submit" id="edit-submit" name="op" type="submit" value="Search"/></div></div></form> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <!-- main-menu region -->
#  <div class="main-menu-wrapper full-width clearfix" id="main-menu-wrapper">
#  <div class="region region-main-menu main-menu grid12-12" id="main-menu">
#  <div class="main-menu-inner inner" id="main-menu-inner">
#  <div class="block block-block first odd" id="block-block-23">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <p><a href="/ls/jgsom" title="John Gokongwei School of Management Home">John Gokongwei School of Management</a> </p>
#  </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-superfish last even" id="block-superfish-15">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="sf-menu menu-jgsom sf-horizontal sf-style-none sf-total-items-6 sf-parent-items-3 sf-single-items-3" id="superfish-15"><li class="first odd sf-item-1 sf-depth-1 sf-no-children" id="menu-2714-15"><a class="sf-depth-1" href="http://www.ateneo.edu/ls/jgsom/about-us/message-dean">About Us</a></li><li class="middle even sf-item-2 sf-depth-1 sf-total-children-4 sf-parent-children-0 sf-single-children-4 menuparent" id="menu-2719-15"><span class="sf-depth-1 menuparent nolink">Departments</span><ul><li class="first odd sf-item-1 sf-depth-2 sf-no-children" id="menu-3665-15"><a class="sf-depth-2" href="/ls/jgsom/finance-accounting">Finance &amp; Accounting</a></li><li class="middle even sf-item-2 sf-depth-2 sf-no-children" id="menu-3664-15"><a class="sf-depth-2" href="/ls/jgsom/leadership-strategy">Leadership &amp; Strategy</a></li><li class="middle odd sf-item-3 sf-depth-2 sf-no-children" id="menu-3663-15"><a class="sf-depth-2" href="/ls/jgsom/marketing-law">Marketing &amp; Law</a></li><li class="last even sf-item-4 sf-depth-2 sf-no-children" id="menu-3662-15"><a class="sf-depth-2" href="/ls/jgsom/qmit">Quantitative Methods &amp; Information Technology</a></li></ul></li><li class="middle odd sf-item-3 sf-depth-1 sf-total-children-11 sf-parent-children-0 sf-single-children-11 menuparent" id="menu-3197-15"><span class="sf-depth-1 menuparent nolink">Degree Programs</span><ul><li class="first odd sf-item-1 sf-depth-2 sf-no-children" id="menu-8749-15"><a class="sf-depth-2" href="https://www.ateneo.edu/ls/jgsom/jgsom/phd-leadership-studies">PhD in Leadership Studies</a></li><li class="middle even sf-item-2 sf-depth-2 sf-no-children" id="menu-8420-15"><a class="sf-depth-2" href="http://www.ateneo.edu/ls/jgsom/jgsom/ms-sustainability">MS in Sustainability Management</a></li><li class="middle odd sf-item-3 sf-depth-2 sf-no-children" id="menu-9177-15"><a class="sf-depth-2" href="http://www.ateneo.edu/ls/jgsom/jgsom/bs-restaurant-entrepreneurship">B.S. Restaurant Entrepreneurship</a></li><li class="middle even sf-item-4 sf-depth-2 sf-no-children" id="menu-3670-15"><a class="sf-depth-2" href="/ls/jgsom/bs-information-technology-entrepreneurship">B.S Information Technology Entrepreneurship</a></li><li class="middle odd sf-item-5 sf-depth-2 sf-no-children" id="menu-3671-15"><a class="sf-depth-2" href="/ls/jgsom/bs-management-applied-chemistry">B.S Management of Applied Chemistry</a></li><li class="middle even sf-item-6 sf-depth-2 sf-no-children" id="menu-3672-15"><a class="sf-depth-2" href="/ls/jgsom/bachelor-science-management">B.S Management</a></li><li class="middle odd sf-item-7 sf-depth-2 sf-no-children" id="menu-3673-15"><a class="sf-depth-2" href="/ls/jgsom/bs-management-honors-program">B.S Management Honors Program</a></li><li class="middle even sf-item-8 sf-depth-2 sf-no-children" id="menu-3674-15"><a class="sf-depth-2" href="/ls/jgsom/bachelor-science-management-engineering">B.S Management Engineering</a></li><li class="middle odd sf-item-9 sf-depth-2 sf-no-children" id="menu-3675-15"><a class="sf-depth-2" href="/ls/jgsom/bachelor-science-communications-technology-management">B.S Communications Technology Management</a></li><li class="middle even sf-item-10 sf-depth-2 sf-no-children" id="menu-3677-15"><a class="sf-depth-2" href="/ls/jgsom/bs-management-major-legal-management">B.S Management Major in Legal Management</a></li><li class="last odd sf-item-11 sf-depth-2 sf-no-children" id="menu-8421-15"><a class="sf-depth-2" href="http://www.ateneo.edu/ls/jgsom/jgsom/jgsom-minor-programs">Minors</a></li></ul></li><li class="middle even sf-item-4 sf-depth-1 sf-no-children" id="menu-2717-15"><a class="sf-depth-1" href="/">Research &amp; Projects</a></li><li class="middle odd sf-item-5 sf-depth-1 sf-total-children-3 sf-parent-children-1 sf-single-children-2 menuparent" id="menu-2716-15"><span class="sf-depth-1 menuparent nolink">Centers</span><ul><li class="first odd sf-item-1 sf-depth-2 sf-no-children" id="menu-3827-15"><a class="sf-de ...
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  </div><!-- /main-menu-inner -->
#  </div><!-- /main-menu -->
#  </div><!-- /main-menu-wrapper -->
#  </div><!-- /header-group-inner -->
#  </div><!-- /header-group -->
#  </div><!-- /header-group-wrapper -->
#  <!-- preface-top region -->
#  <div class="preface-top-wrapper full-width clearfix" id="preface-top-wrapper">
#  <div class="region region-preface-top preface-top grid12-12" id="preface-top">
#  <div class="preface-top-inner inner" id="preface-top-inner">
#  <div class="block block-block first last odd" id="block-block-66">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <p><a href="/ls/jgsom/qmit">Quantitative Methods &amp; Information Technology</a></p>
#  </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  </div><!-- /preface-top-inner -->
#  </div><!-- /preface-top -->
#  </div><!-- /preface-top-wrapper -->
#  <!-- main region: width = grid_width -->
#  <div class="main-wrapper full-width clearfix" id="main-wrapper">
#  <div class="main region grid12-12" id="main">
#  <div class="main-inner inner clearfix" id="main-inner">
#  <!-- sidebar-first region -->
#  <div class="region region-sidebar-first sidebar-first nested grid12-3 sidebar" id="sidebar-first">
#  <div class="sidebar-first-inner inner" id="sidebar-first-inner">
#  <div class="block block-menu dept-jgsom-menu first last odd" id="block-menu-menu-jgsom-qmit">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="menu"><li class="first leaf"><a href="/ls/jgsom/qmit">About</a></li>
#  <li class="leaf"><a href="/ls/jgsom/qmit/message-chair">Message From Chair</a></li>
#  <li class="leaf"><a href="/ls/jgsom/qmit/list-classes">List Of Classes</a></li>
#  <li class="leaf active-trail"><a class="active-trail active" href="/ls/jgsom/qmit/faculty">Faculty</a></li>
#  <li class="last leaf"><a href="/ls/jgsom/qmit/contact-information">Contact Information</a></li>
#  </ul> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  </div><!-- /sidebar-first-inner -->
#  </div><!-- /sidebar-first -->
#  <!-- main group: width = grid_width - sidebar_first_width -->
#  <div class="main-group region nested grid12-9" id="main-group">
#  <div class="main-group-inner inner" id="main-group-inner">
#  <div class="main-content region nested" id="main-content">
#  <div class="main-content-inner inner" id="main-content-inner">
#  <!-- content group: width = grid_width - sidebar_first_width - sidebar_second_width -->
#  <div class="content-group region nested grid12-9" id="content-group">
#  <div class="content-group-inner inner" id="content-group-inner">
#  <div class="breadcrumbs block" id="breadcrumbs">
#  <div class="breadcrumbs-inner gutter" id="breadcrumbs-inner">
#  <h2 class="element-invisible">You are here</h2><div class="breadcrumb"><div class="inline odd first" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="http://www.ateneo.edu/" itemprop="url"><span itemprop="title">Home</span></a></div> » <div class="inline even" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="http://www.ateneo.edu/ls" itemprop="url"><span itemprop="title">Loyola Schools</span></a></div> » <div class="inline odd" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="http://www.ateneo.edu/ls/jgsom" itemprop="url"><span itemprop="title">John Gokongwei School of Management</span></a></div> » <div class="inline even last" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><span itemprop="title">Faculty</span></div></div></div><!-- /breadcrumbs-inner -->
#  </div><!-- /breadcrumbs -->
#  <div class="content-region region nested" id="content-region">
#  <div class="content-region-inner inner" id="content-region-inner">
#  <a id="main-content-area"></a>
#  <h1 class="title gutter">Faculty</h1>
#  <!-- content region -->
#  <div class="region region-content content nested grid12-9" id="content">
#  <div class="content-inner inner" id="content-inner">
#  <div class="block block-system first odd" id="block-system-main">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <div about="/ls/jgsom/qmit/faculty" class="node node-page odd full-node clearfix" id="node-1223" typeof="foaf:Document">
#  <span class="rdf-meta element-hidden" content="Faculty" property="dc:title"></span>
#  <div class="node-top region nested" id="node-top">
#  </div>
#  <div class="content">
#  </div>
#  <div class="node-bottom region nested" id="node-bottom">
#  </div>
#  </div>
#  </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-views last even" id="block-views-profile-block">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <div class="view view-profile view-id-profile view-display-id-block view-dom-id-ac113c5d75aeeb24c5a26cf0001d94ad">
#  <div class="view-filters">
#  <form accept-charset="UTF-8" action="/aps/law/ateneo-law-department/faculty-profile_old1" id="views-exposed-form-profile-block" method="get"><div><div class="views-exposed-form">
#  <div class="views-exposed-widgets clearfix">
#  <div class="views-exposed-widget views-widget-filter-title" id="edit-title-wrapper">
#  <label for="edit-title">
#              Search by Name          </label>
#  <div class="views-operator">
#  <div class="form-item form-type-select form-item-title-op">
#  <select class="form-select" id="edit-title-op" name="title_op"><option value="=">Is equal to</option><option value="!=">Is not equal to</option><option selected="selected" value="contains">Contains</option><option value="word">Contains any word</option><option value="allwords">Contains all words</option><option value="starts">Starts with</option><option value="not_starts">Does not start with</option><option value="ends">Ends with</option><option value="not_ends">Does not end with</option><option value="not">Does not contain</option><option value="shorterthan">Length is shorter than</option><option value="longerthan">Length is longer than</option><option value="regular_expression">Regular expression</option></select>
#  </div>
#  </div>
#  <div class="views-widget">
#  <div class="form-item form-type-textfield form-item-title">
#  <input class="form-text" id="edit-title" maxlength="128" name="title" size="30" type="text" value=""/>
#  </div>
#  </div>
#  </div>
#  <div class="views-exposed-widget views-submit-button">
#  <input class="form-submit" id="edit-submit-profile" name="" type="submit" value="Apply"/> </div>
#  </div>
#  </div>
#  </div></form> </div>
#  <div class="view-content">
#  <table class="views-table cols-1">
#  <thead>
#  <tr>
#  <th class="views-field views-field-nothing">
#  </th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr class="odd views-row-first">
#  <td class="views-field views-field-nothing">
#  <div id="profile-wrapper">
#  <div id="profile-img"><img alt="" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/default_images/default_profile.jpg?itok=BGRUpJ4B" typeof="foaf:Image"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/agbayani-victor-e">Agbayani, Victor E.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#  		Part-Time Faculty, Quantitative Methods &amp; Information Technology
#
#  <br/><a href="mailto:vagbayani@ateneo.edu">vagbayani@ateneo.edu</a><br/></div>
#  </div>
#  </div> </td>
#  </tr>
#  <tr class="even">
#  <td class="views-field views-field-nothing">
#  <div id="profile-wrapper">
#  <div id="profile-img"><img alt="" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/default_images/default_profile.jpg?itok=BGRUpJ4B" typeof="foaf:Image"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/amurao-marianne-kayle-h">Amurao, Marianne Kayle H.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#
#
#  		Part-Time Faculty, Quantitative Methods and Information Technology...<br/><a href="mailto:mamurao@ateneo.edu">mamurao@ateneo.edu</a><br/></div>
#  </div>
#  </div> </td>
#  </tr>
#  <tr class="odd">
#  <td class="views-field views-field-nothing">
#  <div id="profile-wrapper">
#  <div id="profile-img"><img alt="" height="100" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/profile-image/Ang-Rodolfo1.jpg?itok=B3yXSXcY" typeof="foaf:Image" width="96"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/ang-rodolfo-p">Ang, Rodolfo P.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#
#
#  		Part-Time Faculty, Quantitative Methods and Information Technology...<br/><a href="mailto:rang@ateneo.edu">rang@ateneo.edu</a><br/></div>
#  </div>
#  </div> </td>
#  </tr>
#  <tr class="even">
#  <td class="views-field views-field-nothing">
#  <div id="profile-wrapper">
#  <div id="profile-img"><img alt="" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/default_images/default_profile.jpg?itok=BGRUpJ4B" typeof="foaf:Image"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/aquino-rafael-alfonso-h">Aquino, Rafael Alfonso H.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#  		Part-Time Faculty, Quantitative Methods &amp; Information Technology
#
#  <br/><a href="mailto:rhaquino@ateneo.edu">rhaquino@ateneo.edu</a><br/></div>
#  </div>
#  </div> </td>
#  </tr>
#  <tr class="odd views-row-last">
#  <td class="views-field views-field-nothing">
#  <div id="profile-wrapper">
#  <div id="profile-img"><img alt="" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/default_images/default_profile.jpg?itok=BGRUpJ4B" typeof="foaf:Image"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/asinas-maria-carmen-vicenta-n">Asinas, Maria Carmen Vicenta N.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#  		Part-Time Faculty, Quantitative Methods &amp; Information Technology
#
#  <br/><a href="mailto:masinas@atenoe.edu">masinas@atenoe.edu</a><br/></div>
#  </div>
#  </div> </td>
#  </tr>
#  </tbody>
#  </table>
#  </div>
#  <h2 class="element-invisible">Pages</h2><div class="item-list"><ul class="pager"><li class="pager-current first">1</li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=1" title="Go to page 2">2</a></li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=2" title="Go to page 3">3</a></li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=3" title="Go to page 4">4</a></li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=4" title="Go to page 5">5</a></li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=5" title="Go to page 6">6</a></li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=6" title="Go to page 7">7</a></li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=7" title="Go to page 8">8</a></li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=8" title="Go to page 9">9</a></li>
#  <li class="pager-next"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=1" title="Go to next page">next ›</a></li>
#  <li class="pager-last last"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=9" title="Go to last page">last »</a></li>
#  </ul></div>
#  </div> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  </div><!-- /content-inner -->
#  </div><!-- /content -->
#  </div><!-- /content-region-inner -->
#  </div><!-- /content-region -->
#  </div><!-- /content-group-inner -->
#  </div><!-- /content-group -->
#  </div><!-- /main-content-inner -->
#  </div><!-- /main-content -->
#  </div><!-- /main-group-inner -->
#  </div><!-- /main-group -->
#  </div><!-- /main-inner -->
#  </div><!-- /main -->
#  </div><!-- /main-wrapper -->
#  <!-- footer region -->
#  <div class="footer-wrapper full-width clearfix" id="footer-wrapper">
#  <div class="region region-footer footer grid12-12" id="footer">
#  <div class="footer-inner inner" id="footer-inner">
#  <div class="block block-menu first odd" id="block-menu-menu-ateneo-de-manila-university">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="menu"><li class="first leaf"><a class="first" href="/">Ateneo de Manila University</a></li>
#  <li class="leaf"><a class="white-arrow" href="/grade-school">Grade School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/ajhs">Junior High School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/high-school">High School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/ls">Loyola Schools</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/campus-maps" target="_blank">Campus Maps</a></li>
#  <li class="last leaf"><a class="offices" href="http://www.ateneo.edu/ateneo-campus-directory">Directory</a></li>
#  </ul> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-block even" id="block-block-3">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <p><a href="https://www.ateneo.edu/uaap" target="_blank"><img alt="" src="/sites/default/files/Website%20Footer.png" style="width: 439px; height: 109px;"/></a></p>
#  </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-menu odd" id="block-menu-menu-postcript-menu-1">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="menu"><li class="first leaf"><a href="https://ateneo.edu/udpo/ADMU-Privacy-Policies" target="_blank">Privacy Policy</a></li>
#  <li class="leaf"><a class="first" href="http://www.ateneo.edu/news/emergency-information">Emergency Information</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/ucpro">University Communications</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/career-opportunities-ateneo">Careers</a></li>
#  <li class="last leaf"><a href="http://www.ateneo.edu/feedback">Contact Us</a></li>
#  </ul> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-block even" id="block-block-10">
#  <div class="gutter inner clearfix">
#  <h2 class="title block-title">Follow Us On:</h2>
#  <div class="content clearfix">
#  <!-- AddThis Follow BEGIN -->
#  <div class="addthis_toolbox addthis_default_style">
#  <ul>
#  <li><a addthis:userid="ateneodemanila" class="addthis_button_facebook_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_twitter_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_youtube_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="theateneo" class="addthis_button_instagram_follow" style="margin-top:2px;"></a></li>
#  <li><span class="st_sharethis"></span></li>
#  <li><a class="email" href="mailto:webmaster@admu.edu.ph"><img src="/sites/all/modules/socialmedia/icons/levelten/glossy/16x16/email.png" style="margin-top:2px; margin-left:4px;"/></a></li>
#  </ul>
#  </div>
#  <script src="http://s7.addthis.com/js/300/addthis_widget.js#pubid=xa-5075146655e5c36f" type="text/javascript"></script>
#  <!-- AddThis Follow END -->
#  <script src="http://w.sharethis.com/button/buttons.js" type="text/javascript"></script>
#  <script type="text/javascript">
#          stLight.options({
#                  publisher:'8525bf31-4657-4209-9439-c7d6888d68db'
#          });
#  </script> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-block last odd" id="block-block-1">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <p>Ateneo de Manila University Loyola Heights Campus | Katipunan Avenue, Loyola Heights, Quezon City 1108, Philippines | Copyright  2006-2012 | Ateneo de Manila University. All rights reserved.</p>
#  </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  </div><!-- /footer-inner -->
#  </div><!-- /footer -->
#  </div><!-- /footer-wrapper -->
#  </div><!-- /page-inner -->
#  </div>, <div class="page-inner" id="page-inner">
#  <!-- header-group region: width = grid_width -->
#  <div class="header-group-wrapper full-width clearfix" id="header-group-wrapper">
#  <div class="header-group region grid12-12" id="header-group">
#  <div class="header-group-inner inner clearfix" id="header-group-inner">
#  <div class="header-site-info clearfix" id="header-site-info">
#  <div class="header-site-info-inner gutter" id="header-site-info-inner">
#  <div id="logo">
#  <a href="/" title="Ateneo de Manila University Home"><img alt="Ateneo de Manila University Home" src="http://www.ateneo.edu/sites/default/files/masthead1_0.png"/></a>
#  </div>
#  </div><!-- /header-site-info-inner -->
#  </div><!-- /header-site-info -->
#  <div class="block block-superfish first odd" id="block-superfish-17">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="sf-menu menu-loyola-schools sf-horizontal sf-style-none sf-total-items-1 sf-parent-items-1 sf-single-items-0" id="superfish-17"><li class="first odd sf-item-1 sf-depth-1 sf-total-children-4 sf-parent-children-0 sf-single-children-4 menuparent" id="menu-2828-17"><span class="sf-depth-1 menuparent nolink">Loyola Schools</span><ul><li class="first odd sf-item-1 sf-depth-2 sf-no-children" id="menu-2750-17"><a class="sf-depth-2" href="/ls/jgsom">John Gokongwei School of Management</a></li><li class="middle even sf-item-2 sf-depth-2 sf-no-children" id="menu-2747-17"><a class="sf-depth-2" href="/ls/soh">School of Humanities</a></li><li class="middle odd sf-item-3 sf-depth-2 sf-no-children" id="menu-2749-17"><a class="sf-depth-2" href="/ls/sose">School of Science and Engineering</a></li><li class="last even sf-item-4 sf-depth-2 sf-no-children" id="menu-2748-17"><a class="sf-depth-2" href="/ls/soss">School of Social Sciences</a></li></ul></li></ul> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-superfish even" id="block-superfish-6">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="sf-menu menu-main-first sf-horizontal sf-style-none sf-total-items-2 sf-parent-items-0 sf-single-items-2" id="superfish-6"><li class="first odd sf-item-1 sf-depth-1 sf-no-children" id="menu-1956-6"><a class="sf-depth-1" href="/">About</a></li><li class="last even sf-item-2 sf-depth-1 sf-no-children" id="menu-1957-6"><a class="sf-depth-1" href="/index">Index</a></li></ul> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-custom-search-blocks last odd" id="block-custom_search_blocks-1">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <form accept-charset="UTF-8" action="/ls/jgsom/qmit/faculty" class="search-form" id="custom-search-blocks-form-1" method="post"><div><div class="form-item form-type-textfield form-item-custom-search-blocks-form-1">
#  <input class="custom-search-default-value custom-search-box form-text" id="edit-custom-search-blocks-form-1--2" maxlength="128" name="custom_search_blocks_form_1" size="15" type="text" value=""/>
#  </div>
#  <fieldset class="custom_search-popup form-wrapper" id="edit-popup"><div class="fieldset-wrapper"></div></fieldset>
#  <input name="delta" type="hidden" value="1"/>
#  <input name="form_build_id" type="hidden" value="form-MRozykvRg6iW_tkfwphn_ZTXwH8Jykk2LiVMT1hEM7s"/>
#  <input name="form_id" type="hidden" value="custom_search_blocks_form_1"/>
#  <input class="default-text" name="default_text" type="hidden" value=""/>
#  <div class="form-actions form-wrapper" id="edit-actions"><input class="form-submit" id="edit-submit" name="op" type="submit" value="Search"/></div></div></form> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <!-- main-menu region -->
#  <div class="main-menu-wrapper full-width clearfix" id="main-menu-wrapper">
#  <div class="region region-main-menu main-menu grid12-12" id="main-menu">
#  <div class="main-menu-inner inner" id="main-menu-inner">
#  <div class="block block-block first odd" id="block-block-23">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <p><a href="/ls/jgsom" title="John Gokongwei School of Management Home">John Gokongwei School of Management</a> </p>
#  </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-superfish last even" id="block-superfish-15">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="sf-menu menu-jgsom sf-horizontal sf-style-none sf-total-items-6 sf-parent-items-3 sf-single-items-3" id="superfish-15"><li class="first odd sf-item-1 sf-depth-1 sf-no-children" id="menu-2714-15"><a class="sf-depth-1" href="http://www.ateneo.edu/ls/jgsom/about-us/message-dean">About Us</a></li><li class="middle even sf-item-2 sf-depth-1 sf-total-children-4 sf-parent-children-0 sf-single-children-4 menuparent" id="menu-2719-15"><span class="sf-depth-1 menuparent nolink">Departments</span><ul><li class="first odd sf-item-1 sf-depth-2 sf-no-children" id="menu-3665-15"><a class="sf-depth-2" href="/ls/jgsom/finance-accounting">Finance &amp; Accounting</a></li><li class="middle even sf-item-2 sf-depth-2 sf-no-children" id="menu-3664-15"><a class="sf-depth-2" href="/ls/jgsom/leadership-strategy">Leadership &amp; Strategy</a></li><li class="middle odd sf-item-3 sf-depth-2 sf-no-children" id="menu-3663-15"><a class="sf-depth-2" href="/ls/jgsom/marketing-law">Marketing &amp; Law</a></li><li class="last even sf-item-4 sf-depth-2 sf-no-children" id="menu-3662-15"><a class="sf-depth-2" href="/ls/jgsom/qmit">Quantitative Methods &amp; Information Technology</a></li></ul></li><li class="middle odd sf-item-3 sf-depth-1 sf-total-children-11 sf-parent-children-0 sf-single-children-11 menuparent" id="menu-3197-15"><span class="sf-depth-1 menuparent nolink">Degree Programs</span><ul><li class="first odd sf-item-1 sf-depth-2 sf-no-children" id="menu-8749-15"><a class="sf-depth-2" href="https://www.ateneo.edu/ls/jgsom/jgsom/phd-leadership-studies">PhD in Leadership Studies</a></li><li class="middle even sf-item-2 sf-depth-2 sf-no-children" id="menu-8420-15"><a class="sf-depth-2" href="http://www.ateneo.edu/ls/jgsom/jgsom/ms-sustainability">MS in Sustainability Management</a></li><li class="middle odd sf-item-3 sf-depth-2 sf-no-children" id="menu-9177-15"><a class="sf-depth-2" href="http://www.ateneo.edu/ls/jgsom/jgsom/bs-restaurant-entrepreneurship">B.S. Restaurant Entrepreneurship</a></li><li class="middle even sf-item-4 sf-depth-2 sf-no-children" id="menu-3670-15"><a class="sf-depth-2" href="/ls/jgsom/bs-information-technology-entrepreneurship">B.S Information Technology Entrepreneurship</a></li><li class="middle odd sf-item-5 sf-depth-2 sf-no-children" id="menu-3671-15"><a class="sf-depth-2" href="/ls/jgsom/bs-management-applied-chemistry">B.S Management of Applied Chemistry</a></li><li class="middle even sf-item-6 sf-depth-2 sf-no-children" id="menu-3672-15"><a class="sf-depth-2" href="/ls/jgsom/bachelor-science-management">B.S Management</a></li><li class="middle odd sf-item-7 sf-depth-2 sf-no-children" id="menu-3673-15"><a class="sf-depth-2" href="/ls/jgsom/bs-management-honors-program">B.S Management Honors Program</a></li><li class="middle even sf-item-8 sf-depth-2 sf-no-children" id="menu-3674-15"><a class="sf-depth-2" href="/ls/jgsom/bachelor-science-management-engineering">B.S Management Engineering</a></li><li class="middle odd sf-item-9 sf-depth-2 sf-no-children" id="menu-3675-15"><a class="sf-depth-2" href="/ls/jgsom/bachelor-science-communications-technology-management">B.S Communications Technology Management</a></li><li class="middle even sf-item-10 sf-depth-2 sf-no-children" id="menu-3677-15"><a class="sf-depth-2" href="/ls/jgsom/bs-management-major-legal-management">B.S Management Major in Legal Management</a></li><li class="last odd sf-item-11 sf-depth-2 sf-no-children" id="menu-8421-15"><a class="sf-depth-2" href="http://www.ateneo.edu/ls/jgsom/jgsom/jgsom-minor-programs">Minors</a></li></ul></li><li class="middle even sf-item-4 sf-depth-1 sf-no-children" id="menu-2717-15"><a class="sf-depth-1" href="/">Research &amp; Projects</a></li><li class="middle odd sf-item-5 sf-depth-1 sf-total-children-3 sf-parent-children-1 sf-single-children-2 menuparent" id="menu-2716-15"><span class="sf-depth-1 menuparent nolink">Centers</span><ul><li class="first odd sf-item-1 sf-depth-2 sf-no-children" id="menu-3827-15"><a class="sf-de ...
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  </div><!-- /main-menu-inner -->
#  </div><!-- /main-menu -->
#  </div><!-- /main-menu-wrapper -->
#  </div><!-- /header-group-inner -->
#  </div><!-- /header-group -->
#  </div><!-- /header-group-wrapper -->
#  <!-- preface-top region -->
#  <div class="preface-top-wrapper full-width clearfix" id="preface-top-wrapper">
#  <div class="region region-preface-top preface-top grid12-12" id="preface-top">
#  <div class="preface-top-inner inner" id="preface-top-inner">
#  <div class="block block-block first last odd" id="block-block-66">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <p><a href="/ls/jgsom/qmit">Quantitative Methods &amp; Information Technology</a></p>
#  </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  </div><!-- /preface-top-inner -->
#  </div><!-- /preface-top -->
#  </div><!-- /preface-top-wrapper -->
#  <!-- main region: width = grid_width -->
#  <div class="main-wrapper full-width clearfix" id="main-wrapper">
#  <div class="main region grid12-12" id="main">
#  <div class="main-inner inner clearfix" id="main-inner">
#  <!-- sidebar-first region -->
#  <div class="region region-sidebar-first sidebar-first nested grid12-3 sidebar" id="sidebar-first">
#  <div class="sidebar-first-inner inner" id="sidebar-first-inner">
#  <div class="block block-menu dept-jgsom-menu first last odd" id="block-menu-menu-jgsom-qmit">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="menu"><li class="first leaf"><a href="/ls/jgsom/qmit">About</a></li>
#  <li class="leaf"><a href="/ls/jgsom/qmit/message-chair">Message From Chair</a></li>
#  <li class="leaf"><a href="/ls/jgsom/qmit/list-classes">List Of Classes</a></li>
#  <li class="leaf active-trail"><a class="active-trail active" href="/ls/jgsom/qmit/faculty">Faculty</a></li>
#  <li class="last leaf"><a href="/ls/jgsom/qmit/contact-information">Contact Information</a></li>
#  </ul> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  </div><!-- /sidebar-first-inner -->
#  </div><!-- /sidebar-first -->
#  <!-- main group: width = grid_width - sidebar_first_width -->
#  <div class="main-group region nested grid12-9" id="main-group">
#  <div class="main-group-inner inner" id="main-group-inner">
#  <div class="main-content region nested" id="main-content">
#  <div class="main-content-inner inner" id="main-content-inner">
#  <!-- content group: width = grid_width - sidebar_first_width - sidebar_second_width -->
#  <div class="content-group region nested grid12-9" id="content-group">
#  <div class="content-group-inner inner" id="content-group-inner">
#  <div class="breadcrumbs block" id="breadcrumbs">
#  <div class="breadcrumbs-inner gutter" id="breadcrumbs-inner">
#  <h2 class="element-invisible">You are here</h2><div class="breadcrumb"><div class="inline odd first" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="http://www.ateneo.edu/" itemprop="url"><span itemprop="title">Home</span></a></div> » <div class="inline even" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="http://www.ateneo.edu/ls" itemprop="url"><span itemprop="title">Loyola Schools</span></a></div> » <div class="inline odd" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="http://www.ateneo.edu/ls/jgsom" itemprop="url"><span itemprop="title">John Gokongwei School of Management</span></a></div> » <div class="inline even last" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><span itemprop="title">Faculty</span></div></div></div><!-- /breadcrumbs-inner -->
#  </div><!-- /breadcrumbs -->
#  <div class="content-region region nested" id="content-region">
#  <div class="content-region-inner inner" id="content-region-inner">
#  <a id="main-content-area"></a>
#  <h1 class="title gutter">Faculty</h1>
#  <!-- content region -->
#  <div class="region region-content content nested grid12-9" id="content">
#  <div class="content-inner inner" id="content-inner">
#  <div class="block block-system first odd" id="block-system-main">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <div about="/ls/jgsom/qmit/faculty" class="node node-page odd full-node clearfix" id="node-1223" typeof="foaf:Document">
#  <span class="rdf-meta element-hidden" content="Faculty" property="dc:title"></span>
#  <div class="node-top region nested" id="node-top">
#  </div>
#  <div class="content">
#  </div>
#  <div class="node-bottom region nested" id="node-bottom">
#  </div>
#  </div>
#  </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-views last even" id="block-views-profile-block">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <div class="view view-profile view-id-profile view-display-id-block view-dom-id-ac113c5d75aeeb24c5a26cf0001d94ad">
#  <div class="view-filters">
#  <form accept-charset="UTF-8" action="/aps/law/ateneo-law-department/faculty-profile_old1" id="views-exposed-form-profile-block" method="get"><div><div class="views-exposed-form">
#  <div class="views-exposed-widgets clearfix">
#  <div class="views-exposed-widget views-widget-filter-title" id="edit-title-wrapper">
#  <label for="edit-title">
#              Search by Name          </label>
#  <div class="views-operator">
#  <div class="form-item form-type-select form-item-title-op">
#  <select class="form-select" id="edit-title-op" name="title_op"><option value="=">Is equal to</option><option value="!=">Is not equal to</option><option selected="selected" value="contains">Contains</option><option value="word">Contains any word</option><option value="allwords">Contains all words</option><option value="starts">Starts with</option><option value="not_starts">Does not start with</option><option value="ends">Ends with</option><option value="not_ends">Does not end with</option><option value="not">Does not contain</option><option value="shorterthan">Length is shorter than</option><option value="longerthan">Length is longer than</option><option value="regular_expression">Regular expression</option></select>
#  </div>
#  </div>
#  <div class="views-widget">
#  <div class="form-item form-type-textfield form-item-title">
#  <input class="form-text" id="edit-title" maxlength="128" name="title" size="30" type="text" value=""/>
#  </div>
#  </div>
#  </div>
#  <div class="views-exposed-widget views-submit-button">
#  <input class="form-submit" id="edit-submit-profile" name="" type="submit" value="Apply"/> </div>
#  </div>
#  </div>
#  </div></form> </div>
#  <div class="view-content">
#  <table class="views-table cols-1">
#  <thead>
#  <tr>
#  <th class="views-field views-field-nothing">
#  </th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr class="odd views-row-first">
#  <td class="views-field views-field-nothing">
#  <div id="profile-wrapper">
#  <div id="profile-img"><img alt="" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/default_images/default_profile.jpg?itok=BGRUpJ4B" typeof="foaf:Image"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/agbayani-victor-e">Agbayani, Victor E.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#  		Part-Time Faculty, Quantitative Methods &amp; Information Technology
#
#  <br/><a href="mailto:vagbayani@ateneo.edu">vagbayani@ateneo.edu</a><br/></div>
#  </div>
#  </div> </td>
#  </tr>
#  <tr class="even">
#  <td class="views-field views-field-nothing">
#  <div id="profile-wrapper">
#  <div id="profile-img"><img alt="" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/default_images/default_profile.jpg?itok=BGRUpJ4B" typeof="foaf:Image"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/amurao-marianne-kayle-h">Amurao, Marianne Kayle H.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#
#
#  		Part-Time Faculty, Quantitative Methods and Information Technology...<br/><a href="mailto:mamurao@ateneo.edu">mamurao@ateneo.edu</a><br/></div>
#  </div>
#  </div> </td>
#  </tr>
#  <tr class="odd">
#  <td class="views-field views-field-nothing">
#  <div id="profile-wrapper">
#  <div id="profile-img"><img alt="" height="100" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/profile-image/Ang-Rodolfo1.jpg?itok=B3yXSXcY" typeof="foaf:Image" width="96"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/ang-rodolfo-p">Ang, Rodolfo P.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#
#
#  		Part-Time Faculty, Quantitative Methods and Information Technology...<br/><a href="mailto:rang@ateneo.edu">rang@ateneo.edu</a><br/></div>
#  </div>
#  </div> </td>
#  </tr>
#  <tr class="even">
#  <td class="views-field views-field-nothing">
#  <div id="profile-wrapper">
#  <div id="profile-img"><img alt="" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/default_images/default_profile.jpg?itok=BGRUpJ4B" typeof="foaf:Image"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/aquino-rafael-alfonso-h">Aquino, Rafael Alfonso H.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#  		Part-Time Faculty, Quantitative Methods &amp; Information Technology
#
#  <br/><a href="mailto:rhaquino@ateneo.edu">rhaquino@ateneo.edu</a><br/></div>
#  </div>
#  </div> </td>
#  </tr>
#  <tr class="odd views-row-last">
#  <td class="views-field views-field-nothing">
#  <div id="profile-wrapper">
#  <div id="profile-img"><img alt="" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/default_images/default_profile.jpg?itok=BGRUpJ4B" typeof="foaf:Image"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/asinas-maria-carmen-vicenta-n">Asinas, Maria Carmen Vicenta N.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#  		Part-Time Faculty, Quantitative Methods &amp; Information Technology
#
#  <br/><a href="mailto:masinas@atenoe.edu">masinas@atenoe.edu</a><br/></div>
#  </div>
#  </div> </td>
#  </tr>
#  </tbody>
#  </table>
#  </div>
#  <h2 class="element-invisible">Pages</h2><div class="item-list"><ul class="pager"><li class="pager-current first">1</li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=1" title="Go to page 2">2</a></li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=2" title="Go to page 3">3</a></li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=3" title="Go to page 4">4</a></li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=4" title="Go to page 5">5</a></li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=5" title="Go to page 6">6</a></li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=6" title="Go to page 7">7</a></li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=7" title="Go to page 8">8</a></li>
#  <li class="pager-item"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=8" title="Go to page 9">9</a></li>
#  <li class="pager-next"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=1" title="Go to next page">next ›</a></li>
#  <li class="pager-last last"><a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=9" title="Go to last page">last »</a></li>
#  </ul></div>
#  </div> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  </div><!-- /content-inner -->
#  </div><!-- /content -->
#  </div><!-- /content-region-inner -->
#  </div><!-- /content-region -->
#  </div><!-- /content-group-inner -->
#  </div><!-- /content-group -->
#  </div><!-- /main-content-inner -->
#  </div><!-- /main-content -->
#  </div><!-- /main-group-inner -->
#  </div><!-- /main-group -->
#  </div><!-- /main-inner -->
#  </div><!-- /main -->
#  </div><!-- /main-wrapper -->
#  <!-- footer region -->
#  <div class="footer-wrapper full-width clearfix" id="footer-wrapper">
#  <div class="region region-footer footer grid12-12" id="footer">
#  <div class="footer-inner inner" id="footer-inner">
#  <div class="block block-menu first odd" id="block-menu-menu-ateneo-de-manila-university">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="menu"><li class="first leaf"><a class="first" href="/">Ateneo de Manila University</a></li>
#  <li class="leaf"><a class="white-arrow" href="/grade-school">Grade School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/ajhs">Junior High School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/high-school">High School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/ls">Loyola Schools</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/campus-maps" target="_blank">Campus Maps</a></li>
#  <li class="last leaf"><a class="offices" href="http://www.ateneo.edu/ateneo-campus-directory">Directory</a></li>
#  </ul> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-block even" id="block-block-3">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <p><a href="https://www.ateneo.edu/uaap" target="_blank"><img alt="" src="/sites/default/files/Website%20Footer.png" style="width: 439px; height: 109px;"/></a></p>
#  </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-menu odd" id="block-menu-menu-postcript-menu-1">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="menu"><li class="first leaf"><a href="https://ateneo.edu/udpo/ADMU-Privacy-Policies" target="_blank">Privacy Policy</a></li>
#  <li class="leaf"><a class="first" href="http://www.ateneo.edu/news/emergency-information">Emergency Information</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/ucpro">University Communications</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/career-opportunities-ateneo">Careers</a></li>
#  <li class="last leaf"><a href="http://www.ateneo.edu/feedback">Contact Us</a></li>
#  </ul> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-block even" id="block-block-10">
#  <div class="gutter inner clearfix">
#  <h2 class="title block-title">Follow Us On:</h2>
#  <div class="content clearfix">
#  <!-- AddThis Follow BEGIN -->
#  <div class="addthis_toolbox addthis_default_style">
#  <ul>
#  <li><a addthis:userid="ateneodemanila" class="addthis_button_facebook_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_twitter_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_youtube_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="theateneo" class="addthis_button_instagram_follow" style="margin-top:2px;"></a></li>
#  <li><span class="st_sharethis"></span></li>
#  <li><a class="email" href="mailto:webmaster@admu.edu.ph"><img src="/sites/all/modules/socialmedia/icons/levelten/glossy/16x16/email.png" style="margin-top:2px; margin-left:4px;"/></a></li>
#  </ul>
#  </div>
# ...
#  <ul>
#  <li><a addthis:userid="ateneodemanila" class="addthis_button_facebook_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_twitter_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_youtube_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="theateneo" class="addthis_button_instagram_follow" style="margin-top:2px;"></a></li>
#  <li><span class="st_sharethis"></span></li>
#  <li><a class="email" href="mailto:webmaster@admu.edu.ph"><img src="/sites/all/modules/socialmedia/icons/levelten/glossy/16x16/email.png" style="margin-top:2px; margin-left:4px;"/></a></li>
#  </ul>
#  </div>
#  <script src="http://s7.addthis.com/js/300/addthis_widget.js#pubid=xa-5075146655e5c36f" type="text/javascript"></script>
#  <!-- AddThis Follow END -->
#  <script src="http://w.sharethis.com/button/buttons.js" type="text/javascript"></script>
#  <script type="text/javascript">
#          stLight.options({
#                  publisher:'8525bf31-4657-4209-9439-c7d6888d68db'
#          });
#  </script> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-block last odd" id="block-block-1">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <p>Ateneo de Manila University Loyola Heights Campus | Katipunan Avenue, Loyola Heights, Quezon City 1108, Philippines | Copyright  2006-2012 | Ateneo de Manila University. All rights reserved.</p>
#  </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  </div><!-- /footer-inner -->
#  </div>, <div class="footer-inner inner" id="footer-inner">
#  <div class="block block-menu first odd" id="block-menu-menu-ateneo-de-manila-university">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="menu"><li class="first leaf"><a class="first" href="/">Ateneo de Manila University</a></li>
#  <li class="leaf"><a class="white-arrow" href="/grade-school">Grade School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/ajhs">Junior High School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/high-school">High School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/ls">Loyola Schools</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/campus-maps" target="_blank">Campus Maps</a></li>
#  <li class="last leaf"><a class="offices" href="http://www.ateneo.edu/ateneo-campus-directory">Directory</a></li>
#  </ul> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-block even" id="block-block-3">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <p><a href="https://www.ateneo.edu/uaap" target="_blank"><img alt="" src="/sites/default/files/Website%20Footer.png" style="width: 439px; height: 109px;"/></a></p>
#  </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-menu odd" id="block-menu-menu-postcript-menu-1">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="menu"><li class="first leaf"><a href="https://ateneo.edu/udpo/ADMU-Privacy-Policies" target="_blank">Privacy Policy</a></li>
#  <li class="leaf"><a class="first" href="http://www.ateneo.edu/news/emergency-information">Emergency Information</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/ucpro">University Communications</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/career-opportunities-ateneo">Careers</a></li>
#  <li class="last leaf"><a href="http://www.ateneo.edu/feedback">Contact Us</a></li>
#  </ul> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-block even" id="block-block-10">
#  <div class="gutter inner clearfix">
#  <h2 class="title block-title">Follow Us On:</h2>
#  <div class="content clearfix">
#  <!-- AddThis Follow BEGIN -->
#  <div class="addthis_toolbox addthis_default_style">
#  <ul>
#  <li><a addthis:userid="ateneodemanila" class="addthis_button_facebook_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_twitter_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_youtube_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="theateneo" class="addthis_button_instagram_follow" style="margin-top:2px;"></a></li>
#  <li><span class="st_sharethis"></span></li>
#  <li><a class="email" href="mailto:webmaster@admu.edu.ph"><img src="/sites/all/modules/socialmedia/icons/levelten/glossy/16x16/email.png" style="margin-top:2px; margin-left:4px;"/></a></li>
#  </ul>
#  </div>
#  <script src="http://s7.addthis.com/js/300/addthis_widget.js#pubid=xa-5075146655e5c36f" type="text/javascript"></script>
#  <!-- AddThis Follow END -->
#  <script src="http://w.sharethis.com/button/buttons.js" type="text/javascript"></script>
#  <script type="text/javascript">
#          stLight.options({
#                  publisher:'8525bf31-4657-4209-9439-c7d6888d68db'
#          });
#  </script> </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  <div class="block block-block last odd" id="block-block-1">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <p>Ateneo de Manila University Loyola Heights Campus | Katipunan Avenue, Loyola Heights, Quezon City 1108, Philippines | Copyright  2006-2012 | Ateneo de Manila University. All rights reserved.</p>
#  </div>
#  </div><!-- /block-inner -->
#  </div><!-- /block -->
#  </div>, <div class="block block-menu first odd" id="block-menu-menu-ateneo-de-manila-university">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="menu"><li class="first leaf"><a class="first" href="/">Ateneo de Manila University</a></li>
#  <li class="leaf"><a class="white-arrow" href="/grade-school">Grade School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/ajhs">Junior High School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/high-school">High School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/ls">Loyola Schools</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/campus-maps" target="_blank">Campus Maps</a></li>
#  <li class="last leaf"><a class="offices" href="http://www.ateneo.edu/ateneo-campus-directory">Directory</a></li>
#  </ul> </div>
#  </div><!-- /block-inner -->
#  </div>, <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="menu"><li class="first leaf"><a class="first" href="/">Ateneo de Manila University</a></li>
#  <li class="leaf"><a class="white-arrow" href="/grade-school">Grade School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/ajhs">Junior High School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/high-school">High School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/ls">Loyola Schools</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/campus-maps" target="_blank">Campus Maps</a></li>
#  <li class="last leaf"><a class="offices" href="http://www.ateneo.edu/ateneo-campus-directory">Directory</a></li>
#  </ul> </div>
#  </div>, <div class="content clearfix">
#  <ul class="menu"><li class="first leaf"><a class="first" href="/">Ateneo de Manila University</a></li>
#  <li class="leaf"><a class="white-arrow" href="/grade-school">Grade School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/ajhs">Junior High School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/high-school">High School</a></li>
#  <li class="leaf"><a class="white-arrow" href="/ls">Loyola Schools</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/campus-maps" target="_blank">Campus Maps</a></li>
#  <li class="last leaf"><a class="offices" href="http://www.ateneo.edu/ateneo-campus-directory">Directory</a></li>
#  </ul> </div>, <div class="block block-block even" id="block-block-3">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <p><a href="https://www.ateneo.edu/uaap" target="_blank"><img alt="" src="/sites/default/files/Website%20Footer.png" style="width: 439px; height: 109px;"/></a></p>
#  </div>
#  </div><!-- /block-inner -->
#  </div>, <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <p><a href="https://www.ateneo.edu/uaap" target="_blank"><img alt="" src="/sites/default/files/Website%20Footer.png" style="width: 439px; height: 109px;"/></a></p>
#  </div>
#  </div>, <div class="content clearfix">
#  <p><a href="https://www.ateneo.edu/uaap" target="_blank"><img alt="" src="/sites/default/files/Website%20Footer.png" style="width: 439px; height: 109px;"/></a></p>
#  </div>, <div class="block block-menu odd" id="block-menu-menu-postcript-menu-1">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="menu"><li class="first leaf"><a href="https://ateneo.edu/udpo/ADMU-Privacy-Policies" target="_blank">Privacy Policy</a></li>
#  <li class="leaf"><a class="first" href="http://www.ateneo.edu/news/emergency-information">Emergency Information</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/ucpro">University Communications</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/career-opportunities-ateneo">Careers</a></li>
#  <li class="last leaf"><a href="http://www.ateneo.edu/feedback">Contact Us</a></li>
#  </ul> </div>
#  </div><!-- /block-inner -->
#  </div>, <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <ul class="menu"><li class="first leaf"><a href="https://ateneo.edu/udpo/ADMU-Privacy-Policies" target="_blank">Privacy Policy</a></li>
#  <li class="leaf"><a class="first" href="http://www.ateneo.edu/news/emergency-information">Emergency Information</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/ucpro">University Communications</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/career-opportunities-ateneo">Careers</a></li>
#  <li class="last leaf"><a href="http://www.ateneo.edu/feedback">Contact Us</a></li>
#  </ul> </div>
#  </div>, <div class="content clearfix">
#  <ul class="menu"><li class="first leaf"><a href="https://ateneo.edu/udpo/ADMU-Privacy-Policies" target="_blank">Privacy Policy</a></li>
#  <li class="leaf"><a class="first" href="http://www.ateneo.edu/news/emergency-information">Emergency Information</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/ucpro">University Communications</a></li>
#  <li class="leaf"><a href="http://www.ateneo.edu/career-opportunities-ateneo">Careers</a></li>
#  <li class="last leaf"><a href="http://www.ateneo.edu/feedback">Contact Us</a></li>
#  </ul> </div>, <div class="block block-block even" id="block-block-10">
#  <div class="gutter inner clearfix">
#  <h2 class="title block-title">Follow Us On:</h2>
#  <div class="content clearfix">
#  <!-- AddThis Follow BEGIN -->
#  <div class="addthis_toolbox addthis_default_style">
#  <ul>
#  <li><a addthis:userid="ateneodemanila" class="addthis_button_facebook_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_twitter_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_youtube_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="theateneo" class="addthis_button_instagram_follow" style="margin-top:2px;"></a></li>
#  <li><span class="st_sharethis"></span></li>
#  <li><a class="email" href="mailto:webmaster@admu.edu.ph"><img src="/sites/all/modules/socialmedia/icons/levelten/glossy/16x16/email.png" style="margin-top:2px; margin-left:4px;"/></a></li>
#  </ul>
#  </div>
#  <script src="http://s7.addthis.com/js/300/addthis_widget.js#pubid=xa-5075146655e5c36f" type="text/javascript"></script>
#  <!-- AddThis Follow END -->
#  <script src="http://w.sharethis.com/button/buttons.js" type="text/javascript"></script>
#  <script type="text/javascript">
#          stLight.options({
#                  publisher:'8525bf31-4657-4209-9439-c7d6888d68db'
#          });
#  </script> </div>
#  </div><!-- /block-inner -->
#  </div>, <div class="gutter inner clearfix">
#  <h2 class="title block-title">Follow Us On:</h2>
#  <div class="content clearfix">
#  <!-- AddThis Follow BEGIN -->
#  <div class="addthis_toolbox addthis_default_style">
#  <ul>
#  <li><a addthis:userid="ateneodemanila" class="addthis_button_facebook_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_twitter_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_youtube_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="theateneo" class="addthis_button_instagram_follow" style="margin-top:2px;"></a></li>
#  <li><span class="st_sharethis"></span></li>
#  <li><a class="email" href="mailto:webmaster@admu.edu.ph"><img src="/sites/all/modules/socialmedia/icons/levelten/glossy/16x16/email.png" style="margin-top:2px; margin-left:4px;"/></a></li>
#  </ul>
#  </div>
#  <script src="http://s7.addthis.com/js/300/addthis_widget.js#pubid=xa-5075146655e5c36f" type="text/javascript"></script>
#  <!-- AddThis Follow END -->
#  <script src="http://w.sharethis.com/button/buttons.js" type="text/javascript"></script>
#  <script type="text/javascript">
#          stLight.options({
#                  publisher:'8525bf31-4657-4209-9439-c7d6888d68db'
#          });
#  </script> </div>
#  </div>, <div class="content clearfix">
#  <!-- AddThis Follow BEGIN -->
#  <div class="addthis_toolbox addthis_default_style">
#  <ul>
#  <li><a addthis:userid="ateneodemanila" class="addthis_button_facebook_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_twitter_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_youtube_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="theateneo" class="addthis_button_instagram_follow" style="margin-top:2px;"></a></li>
#  <li><span class="st_sharethis"></span></li>
#  <li><a class="email" href="mailto:webmaster@admu.edu.ph"><img src="/sites/all/modules/socialmedia/icons/levelten/glossy/16x16/email.png" style="margin-top:2px; margin-left:4px;"/></a></li>
#  </ul>
#  </div>
#  <script src="http://s7.addthis.com/js/300/addthis_widget.js#pubid=xa-5075146655e5c36f" type="text/javascript"></script>
#  <!-- AddThis Follow END -->
#  <script src="http://w.sharethis.com/button/buttons.js" type="text/javascript"></script>
#  <script type="text/javascript">
#          stLight.options({
#                  publisher:'8525bf31-4657-4209-9439-c7d6888d68db'
#          });
#  </script> </div>, <div class="addthis_toolbox addthis_default_style">
#  <ul>
#  <li><a addthis:userid="ateneodemanila" class="addthis_button_facebook_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_twitter_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="ateneodemanilau" class="addthis_button_youtube_follow" style="margin-top:2px;"></a></li>
#  <li><a addthis:userid="theateneo" class="addthis_button_instagram_follow" style="margin-top:2px;"></a></li>
#  <li><span class="st_sharethis"></span></li>
#  <li><a class="email" href="mailto:webmaster@admu.edu.ph"><img src="/sites/all/modules/socialmedia/icons/levelten/glossy/16x16/email.png" style="margin-top:2px; margin-left:4px;"/></a></li>
#  </ul>
#  </div>, <div class="block block-block last odd" id="block-block-1">
#  <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <p>Ateneo de Manila University Loyola Heights Campus | Katipunan Avenue, Loyola Heights, Quezon City 1108, Philippines | Copyright  2006-2012 | Ateneo de Manila University. All rights reserved.</p>
#  </div>
#  </div><!-- /block-inner -->
#  </div>, <div class="gutter inner clearfix">
#  <div class="content clearfix">
#  <p>Ateneo de Manila University Loyola Heights Campus | Katipunan Avenue, Loyola Heights, Quezon City 1108, Philippines | Copyright  2006-2012 | Ateneo de Manila University. All rights reserved.</p>
#  </div>
#  </div>, <div class="content clearfix">
#  <p>Ateneo de Manila University Loyola Heights Campus | Katipunan Avenue, Loyola Heights, Quezon City 1108, Philippines | Copyright  2006-2012 | Ateneo de Manila University. All rights reserved.</p>
#  </div>]

# %%
soup.find_all(id='profile-wrapper')
# Out:
# [<div id="profile-wrapper">
#  <div id="profile-img"><img alt="" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/default_images/default_profile.jpg?itok=BGRUpJ4B" typeof="foaf:Image"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/agbayani-victor-e">Agbayani, Victor E.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#  		Part-Time Faculty, Quantitative Methods &amp; Information Technology
#
#  <br/><a href="mailto:vagbayani@ateneo.edu">vagbayani@ateneo.edu</a><br/></div>
#  </div>
#  </div>, <div id="profile-wrapper">
#  <div id="profile-img"><img alt="" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/default_images/default_profile.jpg?itok=BGRUpJ4B" typeof="foaf:Image"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/amurao-marianne-kayle-h">Amurao, Marianne Kayle H.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#
#
#  		Part-Time Faculty, Quantitative Methods and Information Technology...<br/><a href="mailto:mamurao@ateneo.edu">mamurao@ateneo.edu</a><br/></div>
#  </div>
#  </div>, <div id="profile-wrapper">
#  <div id="profile-img"><img alt="" height="100" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/profile-image/Ang-Rodolfo1.jpg?itok=B3yXSXcY" typeof="foaf:Image" width="96"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/ang-rodolfo-p">Ang, Rodolfo P.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#
#
#  		Part-Time Faculty, Quantitative Methods and Information Technology...<br/><a href="mailto:rang@ateneo.edu">rang@ateneo.edu</a><br/></div>
#  </div>
#  </div>, <div id="profile-wrapper">
#  <div id="profile-img"><img alt="" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/default_images/default_profile.jpg?itok=BGRUpJ4B" typeof="foaf:Image"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/aquino-rafael-alfonso-h">Aquino, Rafael Alfonso H.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#  		Part-Time Faculty, Quantitative Methods &amp; Information Technology
#
#  <br/><a href="mailto:rhaquino@ateneo.edu">rhaquino@ateneo.edu</a><br/></div>
#  </div>
#  </div>, <div id="profile-wrapper">
#  <div id="profile-img"><img alt="" src="http://www.ateneo.edu/sites/default/files/styles/thumbnail/public/default_images/default_profile.jpg?itok=BGRUpJ4B" typeof="foaf:Image"/></div>
#  <div id="profile-body">
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/asinas-maria-carmen-vicenta-n">Asinas, Maria Carmen Vicenta N.</a></div>
#  <div id="profile-body-contact">
#  	Ateneo de Manila University
#
#
#  		Part-Time Faculty, Quantitative Methods &amp; Information Technology
#
#  <br/><a href="mailto:masinas@atenoe.edu">masinas@atenoe.edu</a><br/></div>
#  </div>
#  </div>]

# %%
soup.find_all(id='profile-body-title')
# Out:
# [<div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/agbayani-victor-e">Agbayani, Victor E.</a></div>,
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/amurao-marianne-kayle-h">Amurao, Marianne Kayle H.</a></div>,
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/ang-rodolfo-p">Ang, Rodolfo P.</a></div>,
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/aquino-rafael-alfonso-h">Aquino, Rafael Alfonso H.</a></div>,
#  <div id="profile-body-title"><a href="/ls/jgsom/qmit/faculty/asinas-maria-carmen-vicenta-n">Asinas, Maria Carmen Vicenta N.</a></div>]

# %%
# what is the type of the returned value of find_all?
type(soup.find_all(id='profile-body-title'))
# Out:
# bs4.element.ResultSet

# %%
[d.string for d in soup.find_all(id='profile-body-title')]
# Out:
# ['Agbayani, Victor E.',
#  'Amurao, Marianne Kayle H.',
#  'Ang, Rodolfo P.',
#  'Aquino, Rafael Alfonso H.',
#  'Asinas, Maria Carmen Vicenta N.']

# %%
next=soup.find(title="Go to next page")
next
# Out:
# <a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=1" title="Go to next page">next ›</a>

# %%
next_url = next["href"]
next_url
# Out:
# '/ls/jgsom/qmit/faculty?title_op=contains&title=&page=1'

# %%
ateneo_website = "http://www.ateneo.edu"
result = requests.get(ateneo_website+next_url)
result
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(result.text)

# %%
[d.string for d in soup.find_all(id='profile-body-title')]
# Out:
# ['Bornilla, Lisha Mae F.',
#  'Cabasag Jr., Francisco A.',
#  'Cadeliña, Ian Christian Ver P.',
#  'Caluag, Jose Antonio I.',
#  'Cham, Lance Samuel S.']

# %%
next=soup.find(title="Go to next page")
next
# Out:
# <a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=2" title="Go to next page">next ›</a>

# %%
next_url = next["href"]
next_url
# Out:
# '/ls/jgsom/qmit/faculty?title_op=contains&title=&page=2'

# %%
result = requests.get(ateneo_website+next_url)
result
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(result.text)

# %%
[d.string for d in soup.find_all(id='profile-body-title')]
# Out:
# ['Chua Jr., Robin A.',
#  'Chua, Magnolia Ann N.',
#  'Denzon, Eduardo Ezekiel S.',
#  'Divinagracia, Gerald G.',
#  'Duque, Marc Wendolf N. ']

# %%
next=soup.find(title="Go to next page")
next
# Out:
# <a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=3" title="Go to next page">next ›</a>

# %%
next_url = next["href"]
next_url
# Out:
# '/ls/jgsom/qmit/faculty?title_op=contains&title=&page=3'

# %%
result = requests.get(ateneo_website+next_url)
result
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(result.text)

# %%
[d.string for d in soup.find_all(id='profile-body-title')]
# Out:
# ['Encarnacion, Rige Bernadette R.',
#  'Filart, Jan Paul G.',
#  'Gan, Wilson Q.',
#  'Gonzales, Joaquin Emmanuel J.',
#  'Gotera, Kristine Mae C.']

# %%
next=soup.find(title="Go to next page")
next
# Out:
# <a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=4" title="Go to next page">next ›</a>

# %%
next_url = next["href"]
next_url
# Out:
# '/ls/jgsom/qmit/faculty?title_op=contains&title=&page=4'

# %%
result = requests.get(ateneo_website+next_url)
result
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(result.text)

# %%
[d.string for d in soup.find_all(id='profile-body-title')]
# Out:
# ['Hernandez, Gio Mari S.',
#  'Ilagan, Joseph Benjamin R.',
#  'Ingco III, Julio S.',
#  'Iyog, Jonathan Marel M.',
#  'Jimenez, Edward G.']

# %%
# this one won't have anything anymore
next=soup.find(title="Go to next page")
print(next)
# Out:
# <a href="/ls/jgsom/qmit/faculty?title_op=contains&amp;title=&amp;page=5" title="Go to next page">next ›</a>

# %% [markdown]
# ### Exercise:
#
# Convert the above to a loop until no more 'Go to next page' can be found

# %%
from bs4 import BeautifulSoup
import requests

ateneo_website = "http://www.ateneo.edu"
result = requests.get(ateneo_website+"/ls/jgsom/qmit/faculty")
result.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(result.text)
[s.text for s in soup.find_all(id='profile-body-contact')]
# Out:
# ['\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nvagbayani@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\xa0\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods and Information Technology...mamurao@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\xa0\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods and Information Technology...rang@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nrhaquino@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nmasinas@atenoe.edu']

# %%
faculty_name = []
faculty_contact = []
result = requests.get("http://www.ateneo.edu/ls/jgsom/qmit/faculty")
if(result.status_code==200):
    soup = soup = BeautifulSoup(result.text)
    faculty_name+=[d.string for d in soup.find_all(id='profile-body-title')]
    faculty_contact+=[s.text for s in soup.find_all(id='profile-body-contact')]
    next=soup.find(title="Go to next page")
    while(next!=None):
        next_url = next["href"]
        print("Fetching...")
        result = requests.get(ateneo_website+next_url)
        soup = BeautifulSoup(result.text)
        faculty_name+=[d.string for d in soup.find_all(id='profile-body-title')]
        faculty_contact+=[s.text for s in soup.find_all(id='profile-body-contact')]
        next=soup.find(title="Go to next page")
        
[n for n in faculty_name]
# Out:
# Fetching...
# Fetching...
# Fetching...
# Fetching...
# Fetching...
# Fetching...
# Fetching...
# Fetching...
# Fetching...
# ['Agbayani, Victor E.',
#  'Amurao, Marianne Kayle H.',
#  'Ang, Rodolfo P.',
#  'Aquino, Rafael Alfonso H.',
#  'Asinas, Maria Carmen Vicenta N.',
#  'Bornilla, Lisha Mae F.',
#  'Cabasag Jr., Francisco A.',
#  'Cadeliña, Ian Christian Ver P.',
#  'Caluag, Jose Antonio I.',
#  'Cham, Lance Samuel S.',
#  'Chua Jr., Robin A.',
#  'Chua, Magnolia Ann N.',
#  'Denzon, Eduardo Ezekiel S.',
#  'Divinagracia, Gerald G.',
#  'Duque, Marc Wendolf N. ',
#  'Encarnacion, Rige Bernadette R.',
#  'Filart, Jan Paul G.',
#  'Gan, Wilson Q.',
#  'Gonzales, Joaquin Emmanuel J.',
#  'Gotera, Kristine Mae C.',
#  'Hernandez, Gio Mari S.',
#  'Ilagan, Joseph Benjamin R.',
#  'Ingco III, Julio S.',
#  'Iyog, Jonathan Marel M.',
#  'Jimenez, Edward G.',
#  'Le Baut, Thierry',
#  'Mariano, Annalisa Margarita V.',
#  'Olpoc, Joselito C.',
#  'Ong, Erwin Donavan S.',
#  'Ongcangco, Kristine Claire E.',
#  'Plaza, Eddie Francis Cesar B.',
#  'Rasco, Joseph P.',
#  'Reventar III, Vicente P.',
#  'Rodriguez, Raul P.',
#  'Rueda IV, Jose R.',
#  'Ruiz, Mari-Jo P.',
#  'Sin, Immanuel Gabriel',
#  'Sy Siong Kiao, Rogelio',
#  'Tan, Eldridge Myles L.',
#  'Tan, Karen Cecilia C.',
#  'Tan, Michael C.',
#  'U, Maria Lourdes de Guzman',
#  'Uy, Ivannah B.',
#  'Uy, Matthew Laurence A.',
#  'Valentin, Alvin Patrick M.',
#  'Villegas, Kerish S.',
#  'Yap, Alyson L.']

# %%
[c for c in faculty_contact]
# Out:
# ['\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nvagbayani@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\xa0\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods and Information Technology...mamurao@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\xa0\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods and Information Technology...rang@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nrhaquino@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nmasinas@atenoe.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\n',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nfcabasag@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nicadelina@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\njcaluag@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nlcham@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nrachua@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nmachua@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tFull-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nedenzon@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\ngdivinagracia@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\xa0\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods and Information Technology...mduque@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nrencarnacion@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\njpfilart@ateneo.edu',
#  'Ateneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty,\xa0Quantitative Methods and Information Technology Department...wgan@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tFull-Time Faculty, Quantitative Methods & Information Technology\r\n\r\njjgonzales@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nkgotera@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tFull-Time Faculty, Quantitative Methods & Information Technology\r\n\r\ngmhernandez@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tFull-Time Faculty, Quantitative Methods & Information Technology\r\n\r\njbilagan@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\njingco@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\njiyog@ateneo.edu',
#  '\xa0\r\nAteneo de Manila University\r\n\r\n\t\r\n\t\tFaculty,\xa0Quantitative Methods and Information Technology Department (...djimenez@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\ntlebaut@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\namariano@ateneo.edu',
#  'Ateneo de Manila University\r\n\r\n\t\r\n\t\tChairperson\xa0Quantitative Methods and Information Technology Department...jolpoc@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nerwindonavan@gmail.com',
#  '\r\n\tAteneo de Manila University\r\n\r\n\tPart-Time Faculty, Quantitative Methods & Information Technology\r\nkongcangco@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\neplaza@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\njrasco@ateneo.edu',
#  '\xa0\r\nAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty,\xa0Quantitative Methods and Information Technology...vreventar@ateneo.edu',
#  '\xa0\r\nAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty,\xa0Quantitative Methods and Information Technology...rprodriguez@ateneo.eduraul_p_rodriguez@yahoo.com',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\njrueda@ateneo.edu',
#  'Ateneo de Manila University\r\n\r\n\t\r\n\t\tMember, Board of Trustees (2005 - Present)\r\n\t\r\n\t\tProfessor Emeritus, Mathematics...mruiz@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nisin@ateneo.edu',
#  'Ateneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty,\xa0Quantitative Methods and Information Technology Department...rsysiongkiao@ateneo.edusysiongk@hotmail.com',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\neltan@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nkcctan@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tFull-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nmctan@ateneo.edu',
#  '\xa0\r\nAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty,\xa0Quantitative Methods and Information Technology...mdeguzman-u@ateneo.edumalu_de_guzman@yahoo.com',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tPart-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nibuy@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tFull-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nmluy@ateneo.edu',
#  'Coordinator for Student Exchange, John Gokongwei School of Managementavalentin@ateneo.edu',
#  '\r\n\tAteneo de Manila University\r\n\r\n\t\r\n\t\tFull-Time Faculty, Quantitative Methods & Information Technology\r\n\r\nkvillegas@ateneo.edu',
#  'Ateneo de Manila University\r\n\r\n\t\r\n\t\tFull-Time Faculty, Quantitative Methods and Information Technology Department...ayap@ateneo.edu426-6001 loc. 5541']

# %%
import pandas as pd

df = pd.DataFrame({"name":faculty_name,"contact":faculty_contact})

# %%
df
# Out:
#                                name  \
# 0               Agbayani, Victor E.
# 1         Amurao, Marianne Kayle H.
# 2                   Ang, Rodolfo P.
# 3         Aquino, Rafael Alfonso H.
# 4   Asinas, Maria Carmen Vicenta N.
# 5            Bornilla, Lisha Mae F.
# 6         Cabasag Jr., Francisco A.
# 7    Cadeliña, Ian Christian Ver P.
# 8           Caluag, Jose Antonio I.
# 9             Cham, Lance Samuel S.
# 10               Chua Jr., Robin A.
# 11            Chua, Magnolia Ann N.
# 12       Denzon, Eduardo Ezekiel S.
# 13          Divinagracia, Gerald G.
# 14          Duque, Marc Wendolf N.
# 15  Encarnacion, Rige Bernadette R.
# 16              Filart, Jan Paul G.
# 17                   Gan, Wilson Q.
# 18    Gonzales, Joaquin Emmanuel J.
# 19          Gotera, Kristine Mae C.
# 20           Hernandez, Gio Mari S.
# 21       Ilagan, Joseph Benjamin R.
# 22              Ingco III, Julio S.
# 23          Iyog, Jonathan Marel M.
# 24               Jimenez, Edward G.
# 25                 Le Baut, Thierry
# 26   Mariano, Annalisa Margarita V.
# 27               Olpoc, Joselito C.
# 28            Ong, Erwin Donavan S.
# 29    Ongcangco, Kristine Claire E.
# 30    Plaza, Eddie Francis Cesar B.
# 31                 Rasco, Joseph P.
# 32         Reventar III, Vicente P.
# 33               Rodriguez, Raul P.
# 34                Rueda IV, Jose R.
# 35                 Ruiz, Mari-Jo P.
# 36            Sin, Immanuel Gabriel
# 37           Sy Siong Kiao, Rogelio
# 38           Tan, Eldridge Myles L.
# 39            Tan, Karen Cecilia C.
# 40                  Tan, Michael C.
# 41       U, Maria Lourdes de Guzman
# 42                   Uy, Ivannah B.
# 43          Uy, Matthew Laurence A.
# 44       Valentin, Alvin Patrick M.
# 45              Villegas, Kerish S.
# 46                   Yap, Alyson L.
#
#                                               contact
# 0   \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 1   \r\n\tAteneo de Manila University\r\n\r\n\t \r...
# 2   \r\n\tAteneo de Manila University\r\n\r\n\t \r...
# 3   \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 4   \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 5   \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 6   \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 7   \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 8   \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 9   \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 10  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 11  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 12  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 13  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 14  \r\n\tAteneo de Manila University\r\n\r\n\t \r...
# 15  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 16  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 17  Ateneo de Manila University\r\n\r\n\t\r\n\t\tP...
# 18  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 19  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 20  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 21  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 22  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 23  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 24   \r\nAteneo de Manila University\r\n\r\n\t\r\n...
# 25  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 26  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 27  Ateneo de Manila University\r\n\r\n\t\r\n\t\tC...
# 28  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 29  \r\n\tAteneo de Manila University\r\n\r\n\tPar...
# 30  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 31  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 32   \r\nAteneo de Manila University\r\n\r\n\t\r\n...
# 33   \r\nAteneo de Manila University\r\n\r\n\t\r\n...
# 34  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 35  Ateneo de Manila University\r\n\r\n\t\r\n\t\tM...
# 36  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 37  Ateneo de Manila University\r\n\r\n\t\r\n\t\tP...
# 38  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 39  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 40  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 41   \r\nAteneo de Manila University\r\n\r\n\t\r\n...
# 42  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 43  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 44  Coordinator for Student Exchange, John Gokongw...
# 45  \r\n\tAteneo de Manila University\r\n\r\n\t\r\...
# 46  Ateneo de Manila University\r\n\r\n\t\r\n\t\tF...

# %%
df.loc[:,"contact"]=df.loc[:,"contact"].replace(r'\r\n','',regex=True).replace(r'\t',' ',regex=True)

# %%
df
# Out:
#                                name  \
# 0               Agbayani, Victor E.
# 1         Amurao, Marianne Kayle H.
# 2                   Ang, Rodolfo P.
# 3         Aquino, Rafael Alfonso H.
# 4   Asinas, Maria Carmen Vicenta N.
# 5            Bornilla, Lisha Mae F.
# 6         Cabasag Jr., Francisco A.
# 7    Cadeliña, Ian Christian Ver P.
# 8           Caluag, Jose Antonio I.
# 9             Cham, Lance Samuel S.
# 10               Chua Jr., Robin A.
# 11            Chua, Magnolia Ann N.
# 12       Denzon, Eduardo Ezekiel S.
# 13          Divinagracia, Gerald G.
# 14          Duque, Marc Wendolf N.
# 15  Encarnacion, Rige Bernadette R.
# 16              Filart, Jan Paul G.
# 17                   Gan, Wilson Q.
# 18    Gonzales, Joaquin Emmanuel J.
# 19          Gotera, Kristine Mae C.
# 20           Hernandez, Gio Mari S.
# 21       Ilagan, Joseph Benjamin R.
# 22              Ingco III, Julio S.
# 23          Iyog, Jonathan Marel M.
# 24               Jimenez, Edward G.
# 25                 Le Baut, Thierry
# 26   Mariano, Annalisa Margarita V.
# 27               Olpoc, Joselito C.
# 28            Ong, Erwin Donavan S.
# 29    Ongcangco, Kristine Claire E.
# 30    Plaza, Eddie Francis Cesar B.
# 31                 Rasco, Joseph P.
# 32         Reventar III, Vicente P.
# 33               Rodriguez, Raul P.
# 34                Rueda IV, Jose R.
# 35                 Ruiz, Mari-Jo P.
# 36            Sin, Immanuel Gabriel
# 37           Sy Siong Kiao, Rogelio
# 38           Tan, Eldridge Myles L.
# 39            Tan, Karen Cecilia C.
# 40                  Tan, Michael C.
# 41       U, Maria Lourdes de Guzman
# 42                   Uy, Ivannah B.
# 43          Uy, Matthew Laurence A.
# 44       Valentin, Alvin Patrick M.
# 45              Villegas, Kerish S.
# 46                   Yap, Alyson L.
#
#                                               contact
# 0    Ateneo de Manila University   Part-Time Facul...
# 1    Ateneo de Manila University     Part-Time Fac...
# 2    Ateneo de Manila University     Part-Time Fac...
# 3    Ateneo de Manila University   Part-Time Facul...
# 4    Ateneo de Manila University   Part-Time Facul...
# 5    Ateneo de Manila University   Part-Time Facul...
# 6    Ateneo de Manila University   Part-Time Facul...
# 7    Ateneo de Manila University   Part-Time Facul...
# 8    Ateneo de Manila University   Part-Time Facul...
# 9    Ateneo de Manila University   Part-Time Facul...
# 10   Ateneo de Manila University   Part-Time Facul...
# 11   Ateneo de Manila University   Part-Time Facul...
# 12   Ateneo de Manila University   Full-Time Facul...
# 13   Ateneo de Manila University   Part-Time Facul...
# 14   Ateneo de Manila University     Part-Time Fac...
# 15   Ateneo de Manila University   Part-Time Facul...
# 16   Ateneo de Manila University   Part-Time Facul...
# 17  Ateneo de Manila University   Part-Time Facult...
# 18   Ateneo de Manila University   Full-Time Facul...
# 19   Ateneo de Manila University   Part-Time Facul...
# 20   Ateneo de Manila University   Full-Time Facul...
# 21   Ateneo de Manila University   Full-Time Facul...
# 22   Ateneo de Manila University   Part-Time Facul...
# 23   Ateneo de Manila University   Part-Time Facul...
# 24   Ateneo de Manila University   Faculty, Quanti...
# 25   Ateneo de Manila University   Part-Time Facul...
# 26   Ateneo de Manila University   Part-Time Facul...
# 27  Ateneo de Manila University   Chairperson Quan...
# 28   Ateneo de Manila University   Part-Time Facul...
# 29   Ateneo de Manila University Part-Time Faculty...
# 30   Ateneo de Manila University   Part-Time Facul...
# 31   Ateneo de Manila University   Part-Time Facul...
# 32   Ateneo de Manila University   Part-Time Facul...
# 33   Ateneo de Manila University   Part-Time Facul...
# 34   Ateneo de Manila University   Part-Time Facul...
# 35  Ateneo de Manila University   Member, Board of...
# 36   Ateneo de Manila University   Part-Time Facul...
# 37  Ateneo de Manila University   Part-Time Facult...
# 38   Ateneo de Manila University   Part-Time Facul...
# 39   Ateneo de Manila University   Part-Time Facul...
# 40   Ateneo de Manila University   Full-Time Facul...
# 41   Ateneo de Manila University   Part-Time Facul...
# 42   Ateneo de Manila University   Part-Time Facul...
# 43   Ateneo de Manila University   Full-Time Facul...
# 44  Coordinator for Student Exchange, John Gokongw...
# 45   Ateneo de Manila University   Full-Time Facul...
# 46  Ateneo de Manila University   Full-Time Facult...

# %%
## just clean when you have time

df.loc[:,"contact"].str.extract(r'\.\.([a-zA-Z\._]+@[a-zA-Z0-9-]+\.[a-zA-Z0-9-.]+)')
# Out:
#                                    0
# 0                                NaN
# 1                .mamurao@ateneo.edu
# 2                   .rang@ateneo.edu
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 11                               NaN
# 12                               NaN
# 13                               NaN
# 14                .mduque@ateneo.edu
# 15                               NaN
# 16                               NaN
# 17                  .wgan@ateneo.edu
# 18                               NaN
# 19                               NaN
# 20                               NaN
# 21                               NaN
# 22                               NaN
# 23                               NaN
# 24              .djimenez@ateneo.edu
# 25                               NaN
# 26                               NaN
# 27                .jolpoc@ateneo.edu
# 28                               NaN
# 29                               NaN
# 30                               NaN
# 31                               NaN
# 32             .vreventar@ateneo.edu
# 33       .rprodriguez@ateneo.eduraul
# 34                               NaN
# 35                 .mruiz@ateneo.edu
# 36                               NaN
# 37  .rsysiongkiao@ateneo.edusysiongk
# 38                               NaN
# 39                               NaN
# 40                               NaN
# 41                               NaN
# 42                               NaN
# 43                               NaN
# 44                               NaN
# 45                               NaN
# 46          .ayap@ateneo.edu426-6001

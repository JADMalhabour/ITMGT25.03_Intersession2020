# %% [markdown]
# # LT 3

# %%
import os
import re

# %% [markdown]
# Get a list of csv files from the *spotify_data* directory

# %%
file_dir = "./spotify_data"
file_list = os.listdir(file_dir)
file_list
# Out:
# ['regional-ph-weekly-2018-08-03--2018-08-10.csv',
#  'regional-ph-weekly-2018-08-17--2018-08-24.csv',
#  'regional-ph-weekly-2018-09-21--2018-09-28.csv',
#  '.DS_Store',
#  'regional-ph-weekly-2019-02-01--2019-02-08.csv',
#  'regional-ph-weekly-2019-05-24--2019-05-31.csv',
#  'regional-ph-weekly-latest.csv',
#  'regional-ph-weekly-2018-11-16--2018-11-23.csv',
#  'regional-ph-weekly-2018-12-28--2019-01-04.csv',
#  'regional-ph-weekly-2018-11-23--2018-11-30.csv',
#  'regional-ph-weekly-2019-02-22--2019-03-01.csv',
#  'regional-ph-weekly-2019-04-19--2019-04-26.csv',
#  'regional-ph-weekly-2019-05-03--2019-05-10.csv',
#  'regional-ph-weekly-2019-06-14--2019-06-21.csv',
#  'regional-ph-weekly-2018-12-07--2018-12-14.csv',
#  'regional-ph-weekly-2019-03-01--2019-03-08.csv',
#  'regional-ph-weekly-2019-06-28--2019-07-05.csv',
#  'regional-ph-weekly-2018-10-05--2018-10-12.csv',
#  'regional-ph-weekly-2019-05-17--2019-05-24.csv',
#  'regional-ph-weekly-2018-08-24--2018-08-31.csv',
# ...

# %%
file_list = [f for f in filter(lambda x: re.search(r"\.csv$", x) , file_list)]

# %%
file_list
# Out:
# ['regional-ph-weekly-2018-08-03--2018-08-10.csv',
#  'regional-ph-weekly-2018-08-17--2018-08-24.csv',
#  'regional-ph-weekly-2018-09-21--2018-09-28.csv',
#  'regional-ph-weekly-2019-02-01--2019-02-08.csv',
#  'regional-ph-weekly-2019-05-24--2019-05-31.csv',
#  'regional-ph-weekly-latest.csv',
#  'regional-ph-weekly-2018-11-16--2018-11-23.csv',
#  'regional-ph-weekly-2018-12-28--2019-01-04.csv',
#  'regional-ph-weekly-2018-11-23--2018-11-30.csv',
#  'regional-ph-weekly-2019-02-22--2019-03-01.csv',
#  'regional-ph-weekly-2019-04-19--2019-04-26.csv',
#  'regional-ph-weekly-2019-05-03--2019-05-10.csv',
#  'regional-ph-weekly-2019-06-14--2019-06-21.csv',
#  'regional-ph-weekly-2018-12-07--2018-12-14.csv',
#  'regional-ph-weekly-2019-03-01--2019-03-08.csv',
#  'regional-ph-weekly-2019-06-28--2019-07-05.csv',
#  'regional-ph-weekly-2018-10-05--2018-10-12.csv',
#  'regional-ph-weekly-2019-05-17--2019-05-24.csv',
#  'regional-ph-weekly-2018-08-24--2018-08-31.csv',
# ...

# %% [markdown]
# Add directory prefix

# %%
file_list = [file_dir+"/"+f for f in file_list]
file_list
# Out:
# ['./spotify_data/regional-ph-weekly-2018-08-03--2018-08-10.csv',
#  './spotify_data/regional-ph-weekly-2018-08-17--2018-08-24.csv',
#  './spotify_data/regional-ph-weekly-2018-09-21--2018-09-28.csv',
#  './spotify_data/regional-ph-weekly-2019-02-01--2019-02-08.csv',
#  './spotify_data/regional-ph-weekly-2019-05-24--2019-05-31.csv',
#  './spotify_data/regional-ph-weekly-latest.csv',
#  './spotify_data/regional-ph-weekly-2018-11-16--2018-11-23.csv',
#  './spotify_data/regional-ph-weekly-2018-12-28--2019-01-04.csv',
#  './spotify_data/regional-ph-weekly-2018-11-23--2018-11-30.csv',
#  './spotify_data/regional-ph-weekly-2019-02-22--2019-03-01.csv',
#  './spotify_data/regional-ph-weekly-2019-04-19--2019-04-26.csv',
#  './spotify_data/regional-ph-weekly-2019-05-03--2019-05-10.csv',
#  './spotify_data/regional-ph-weekly-2019-06-14--2019-06-21.csv',
#  './spotify_data/regional-ph-weekly-2018-12-07--2018-12-14.csv',
#  './spotify_data/regional-ph-weekly-2019-03-01--2019-03-08.csv',
# ...

# %% [markdown]
# Load all csvs as one dataframe

# %%
import pandas as pd

# %%
# exclude first row per file
def load_csv(file_name):
    df = pd.read_csv(file_name, skiprows=1)
    df["file_name"] = file_name
    return df
    
df = pd.concat(map(load_csv, file_list))

# %%
df
# Out:
#      Position                                         Track Name  \
# 0           1                                     In My Feelings
# 1           2                     Girls Like You (feat. Cardi B)
# 2           3                                              Mundo
# 3           4                                   Thru These Tears
# 4           5                                       Kathang Isip
# 5           6                             Kung 'Di Rin Lang Ikaw
# 6           7                                        'Di Na Muli
# 7           8                                               2002
# 8           9                                         No Brainer
# 9          10                            DDU-DU DDU-DU - KR Ver.
# 10         11                                            Tagpuan
# 11         12                                               Rise
# 12         13                    Eastside (with Halsey & Khalid)
# ...

# %% [markdown]
# Clean filename data

# %%
df.loc[:,"file_name"] = df.loc[:,"file_name"].replace(r"\./spotify_data/","",regex=True)
df
# Out:
#      Position                                         Track Name  \
# 0           1                                     In My Feelings
# 1           2                     Girls Like You (feat. Cardi B)
# 2           3                                              Mundo
# 3           4                                   Thru These Tears
# 4           5                                       Kathang Isip
# 5           6                             Kung 'Di Rin Lang Ikaw
# 6           7                                        'Di Na Muli
# 7           8                                               2002
# 8           9                                         No Brainer
# 9          10                            DDU-DU DDU-DU - KR Ver.
# 10         11                                            Tagpuan
# 11         12                                               Rise
# 12         13                    Eastside (with Halsey & Khalid)
# ...

# %%
# Get beginning and ending days (yyyy-mm-dd) of the week as found in the file name
extracted_df = df.loc[:,"file_name"].str.extract(r"([0-9]{4}\-[0-9]{2}\-[0-9]{2})\--([0-9]{4}\-[0-9]{2}\-[0-9]{2})")
extracted_df.columns = ["begin_date","end_date"]
extracted_df.head()
# Out:
#    begin_date    end_date
# 0  2018-08-03  2018-08-10
# 1  2018-08-03  2018-08-10
# 2  2018-08-03  2018-08-10
# 3  2018-08-03  2018-08-10
# 4  2018-08-03  2018-08-10

# %% [markdown]
# Add new columns to dataframe

# %%
#Add new columns to dataframe
df = pd.concat([df,extracted_df],axis=1)

# %%
df
# Out:
#      Position                                         Track Name  \
# 0           1                                     In My Feelings
# 1           2                     Girls Like You (feat. Cardi B)
# 2           3                                              Mundo
# 3           4                                   Thru These Tears
# 4           5                                       Kathang Isip
# 5           6                             Kung 'Di Rin Lang Ikaw
# 6           7                                        'Di Na Muli
# 7           8                                               2002
# 8           9                                         No Brainer
# 9          10                            DDU-DU DDU-DU - KR Ver.
# 10         11                                            Tagpuan
# 11         12                                               Rise
# 12         13                    Eastside (with Halsey & Khalid)
# ...

# %% [markdown]
# Get all unique track names

# %%
tracks = df.loc[:,"Track Name"].unique()
tracks
# Out:
# array(['In My Feelings', 'Girls Like You (feat. Cardi B)', 'Mundo',
#        'Thru These Tears', 'Kathang Isip', "Kung 'Di Rin Lang Ikaw",
#        "'Di Na Muli", '2002', 'No Brainer', 'DDU-DU DDU-DU - KR Ver.',
#        'Tagpuan', 'Rise', 'Eastside (with Halsey & Khalid)',
#        'Sa Ngalan Ng Pag-Ibig', 'God is a woman', 'BAAM', 'BBoom BBoom',
#        'Happy Now', 'Ocean (feat. Khalid)',
#        'Freaky Friday (feat. Chris Brown)', "I'm a Mess", 'Nadarang',
#        'Back To You - From 13 Reasons Why – Season 2 Soundtrack', 'IDGAF',
#        '13', 'Happier', 'The Middle', 'Tadhana', 'Connection',
#        'Solo (feat. Demi Lovato)', 'Tagu-Taguan', 'no tears left to cry',
#        'Youngblood', 'Playinwitme (feat. Kehlani)', 'Born To Be Yours',
#        'Oks Lang', "Don't Leave Me Alone (feat. Anne-Marie)",
#        'Only You (with Little Mix)', 'Midnight Sky',
#        'Too Good At Goodbyes', 'Enemies', "Say You Won't Let Go",
# ...

# %%
track_ids = df.loc[:,"URL"].replace(r'^https://open\.spotify\.com\/track/','',regex=True)
track_ids
track_ids.unique()
# Out:
# array(['2G7V7zsVDxg1yRsu7Ew9RJ', '7fa9MBXhVfQ8P8Df9OEbD8',
#        '4u8RkgV6P4TLi89SmlUtv8', '4gB61mP4tNChn4LgfquMhi',
#        '3WUEs51GpcvlgU7lehLgLh', '2BgD4nRyx9EZ5o8YEnjRSV',
#        '3VQb0rq27GPX92X53Ni1Lc', '6SFStUDQZNaGPKWOx9ZiJB',
#        '5WvAo7DNuPRmk4APhdPzi8', '2CWnuF7ht55Ajyeg4WPvWu',
#        '0ztDBQdQmdVZvorSmIjMih', '3u1S1OmAUhx5DRlLrXqyp3',
#        '0d2iYfpKoM0QCKvcLCkBao', '00mBzIWv5gHOYxwuEJXjOG',
#        '7gkWXbAxIYuvtOpcN3p9GJ', '4Is1b37KJY9XVCgzp81FBW',
#        '3BPoSr2pO34Aan6alFfVto', '4keoy2fqgwGnbWlm3ZVZFa',
#        '3nc420PXjTdBV5TN0gCFkS', '10Igtw8bSDyyFs7KIsKngZ',
#        '04ZTP5KsCypmtCmQg5tH9R', '6LJ1p1h5EcMK4VPeCLDSoF',
#        '4hQ6UGyWQIGJmHSo0J88JW', '76cy1WJvNGJTj78UqeA5zr',
#        '0WOvSEVpUGkNufX0w0M06F', '2RttW7RAu5nOAfq6YFvApB',
#        '09IStsImFySgyp0pIQdqAc', '6NFKf8vBApSvtzkapYmnVR',
#        '3T4UodGkfZObJ43RtA5KFU', '6kPJZM97LwdG9QIsT7khp6',
#        '2iOnWSWcChoGmUufbrQ00e', '5SxkdsY1ufZzoq9iXceLw9',
# ...

# %%
len(track_ids.unique())
# Out:
# 794

# %% [markdown]
# Get all unique artists

# %%
artists = df.loc[:,"Artist"]
artists
# Out:
# 0                    Drake
# 1                 Maroon 5
# 2             IV Of Spades
# 3                     LANY
# 4                  Ben&Ben
# 5          December Avenue
# 6            Janine Teñoso
# 7               Anne-Marie
# 8                DJ Khaled
# 9                BLACKPINK
# 10        Moira Dela Torre
# 11              Jonas Blue
# 12            benny blanco
# 13         December Avenue
# 14           Ariana Grande
# 15                MOMOLAND
# 16                MOMOLAND
# 17                    Zedd
# 18           Martin Garrix
# 19               Lil Dicky
# 20              Bebe Rexha
# 21             Shanti Dope
# 22            Selena Gomez
# 23                Dua Lipa
# 24                    LANY
# 25              Ed Sheeran
# 26                    Zedd
# 27          Up Dharma Down
# 28             OneRepublic
# 29            Clean Bandit
#               ...
# 170        Christina Perri
# 171                   iKON
# 172            Erik Santos
# ...

# %%
import requests
import json

# %%
client_id="da77ef5ab6f14964ab7936fa8b750330"
client_secret="482e21851c084e9395ce967ecacfccbd"
headers = {"Authorization": "Bearer BQAGZa1xsmwbecXWMHnCRcNflVPFobL422m5c-u5afRG1xeEDFiHnT2gNyhXO-CGstXaQ26jt83MSYznuwD7VEGfSYO35AyJVE1tjIXw-is1uJdNE1Fn7rdGTQtuu9CeW2kqL8XFUIlGtyBTwm80mxW5WLsxF7FDDS8_aL0M-I8"}

# %%
def get_track(id):
    response=requests.get("https://api.spotify.com/v1/tracks/{}?market=PH".format(id),headers=headers)
    print(response)
    data=json.loads(response.text)
    return data

# %%
data=get_track("4gB61mP4tNChn4LgfquMhi")
data
# Out:
# <Response [200]>
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/49tQo2QULno7gxHutgccqF'},
#     'href': 'https://api.spotify.com/v1/artists/49tQo2QULno7gxHutgccqF',
#     'id': '49tQo2QULno7gxHutgccqF',
#     'name': 'LANY',
#     'type': 'artist',
#     'uri': 'spotify:artist:49tQo2QULno7gxHutgccqF'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/66Jli9l9UHCoiumUK85Y5z'},
#   'href': 'https://api.spotify.com/v1/albums/66Jli9l9UHCoiumUK85Y5z',
#   'id': '66Jli9l9UHCoiumUK85Y5z',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/82b80fc6ad3d524758ec1cec51b0d69cc84786f9',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/3cb2795ea3bb9ce45b575629b74cb99906806b75',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/fee038679af69fd2d6381a4fcf50e2678b1664bc',
#     'width': 64}],
#   'name': 'Thru These Tears',
# ...

# %%
import time
tracks=[]

no_of_tracks = len(track_ids.unique())
track_count = 0
c = 0
for i in track_ids.unique():
    data=get_track(i)
    data["original_id"]=i
    tracks.append(data)
    print("Track {} of {}...".format(str(c+1),no_of_tracks))
    c+=1
    print(data["id"])
    time.sleep(1)
    
print("Done.")
# Out:
# <Response [200]>
# Track 1 of 794...
# 2G7V7zsVDxg1yRsu7Ew9RJ
# <Response [200]>
# Track 2 of 794...
# 7fa9MBXhVfQ8P8Df9OEbD8
# <Response [200]>
# Track 3 of 794...
# 4u8RkgV6P4TLi89SmlUtv8
# <Response [200]>
# Track 4 of 794...
# 7GbAp0HKPQW7WnFJAzMoRk
# <Response [200]>
# Track 5 of 794...
# 3WUEs51GpcvlgU7lehLgLh
# <Response [200]>
# Track 6 of 794...
# 2BgD4nRyx9EZ5o8YEnjRSV
# <Response [200]>
# Track 7 of 794...
# 6p6DiqAPwMX7vdrSo30wgo
# <Response [200]>
# Track 8 of 794...
# 2BgEsaKNfHUdlh97KmvFyo
# <Response [200]>
# Track 9 of 794...
# 5WvAo7DNuPRmk4APhdPzi8
# <Response [200]>
# Track 10 of 794...
# 7b8YOVV5quZcSKEijDgyWB
# <Response [200]>
# Track 11 of 794...
# 0ztDBQdQmdVZvorSmIjMih
# <Response [200]>
# Track 12 of 794...
# 3u1S1OmAUhx5DRlLrXqyp3
# <Response [200]>
# Track 13 of 794...
# 0d2iYfpKoM0QCKvcLCkBao
# <Response [200]>
# Track 14 of 794...
# 00mBzIWv5gHOYxwuEJXjOG
# <Response [200]>
# Track 15 of 794...
# 5OCJzvD7sykQEKHH7qAC3C
# <Response [200]>
# ...

# %%
with open(file_dir+"/tracks.json","w") as tracks_file:
    json.dump(tracks,tracks_file)

# %%
len(tracks)
# Out:
# 794

# %%
tracks[:5]
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1ATL5GLyefJaxhQzSPVrLX'},
#    'href': 'https://api.spotify.com/v1/albums/1ATL5GLyefJaxhQzSPVrLX',
#    'id': '1ATL5GLyefJaxhQzSPVrLX',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/542d705154be4049fc927050d006987e63739bbd',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/239ec906572231368d8ebd72614094bd3bd10b33',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/f12257240bbec6ddfa780253ac939e646eba2a36',
#      'width': 64}],
#    'name': 'Scorpion',
# ...

# %%
track_ids.unique()
# Out:
# array(['2G7V7zsVDxg1yRsu7Ew9RJ', '7fa9MBXhVfQ8P8Df9OEbD8',
#        '4u8RkgV6P4TLi89SmlUtv8', '4gB61mP4tNChn4LgfquMhi',
#        '3WUEs51GpcvlgU7lehLgLh', '2BgD4nRyx9EZ5o8YEnjRSV',
#        '3VQb0rq27GPX92X53Ni1Lc', '6SFStUDQZNaGPKWOx9ZiJB',
#        '5WvAo7DNuPRmk4APhdPzi8', '2CWnuF7ht55Ajyeg4WPvWu',
#        '0ztDBQdQmdVZvorSmIjMih', '3u1S1OmAUhx5DRlLrXqyp3',
#        '0d2iYfpKoM0QCKvcLCkBao', '00mBzIWv5gHOYxwuEJXjOG',
#        '7gkWXbAxIYuvtOpcN3p9GJ', '4Is1b37KJY9XVCgzp81FBW',
#        '3BPoSr2pO34Aan6alFfVto', '4keoy2fqgwGnbWlm3ZVZFa',
#        '3nc420PXjTdBV5TN0gCFkS', '10Igtw8bSDyyFs7KIsKngZ',
#        '04ZTP5KsCypmtCmQg5tH9R', '6LJ1p1h5EcMK4VPeCLDSoF',
#        '4hQ6UGyWQIGJmHSo0J88JW', '76cy1WJvNGJTj78UqeA5zr',
#        '0WOvSEVpUGkNufX0w0M06F', '2RttW7RAu5nOAfq6YFvApB',
#        '09IStsImFySgyp0pIQdqAc', '6NFKf8vBApSvtzkapYmnVR',
#        '3T4UodGkfZObJ43RtA5KFU', '6kPJZM97LwdG9QIsT7khp6',
#        '2iOnWSWcChoGmUufbrQ00e', '5SxkdsY1ufZzoq9iXceLw9',
# ...

# %%
[{"id":t["id"],"name":t["name"], "duration_ms":t["duration_ms"], "popularity":t["popularity"]} for t in tracks]
# Out:
# [{'id': '2G7V7zsVDxg1yRsu7Ew9RJ',
#   'name': 'In My Feelings',
#   'duration_ms': 217925,
#   'popularity': 82},
#  {'id': '7fa9MBXhVfQ8P8Df9OEbD8',
#   'name': 'Girls Like You (feat. Cardi B)',
#   'duration_ms': 235545,
#   'popularity': 77},
#  {'id': '4u8RkgV6P4TLi89SmlUtv8',
#   'name': 'Mundo',
#   'duration_ms': 349713,
#   'popularity': 65},
#  {'id': '7GbAp0HKPQW7WnFJAzMoRk',
#   'name': 'Thru These Tears',
#   'duration_ms': 204515,
#   'popularity': 69},
#  {'id': '3WUEs51GpcvlgU7lehLgLh',
#   'name': 'Kathang Isip',
#   'duration_ms': 318814,
#   'popularity': 69},
#  {'id': '2BgD4nRyx9EZ5o8YEnjRSV',
#   'name': "Kung 'Di Rin Lang Ikaw",
#   'duration_ms': 267759,
#   'popularity': 71},
#  {'id': '6p6DiqAPwMX7vdrSo30wgo',
#   'name': "'Di Na Muli",
#   'duration_ms': 207018,
#   'popularity': 63},
#  {'id': '2BgEsaKNfHUdlh97KmvFyo',
#   'name': '2002',
#   'duration_ms': 186986,
#   'popularity': 81},
#  {'id': '5WvAo7DNuPRmk4APhdPzi8',
#   'name': 'No Brainer',
# ...

# %%
artist_ids = [t["artists"][0]["id"] for t in tracks]

# %%
len(set(artist_ids))
# Out:
# 304

# %%
artists = set(artist_ids)

# %%
artists
# Out:
# {'042sjIstxjQz7xhDkEayIE',
#  '04gDigrS5kc9YWfZHwBETP',
#  '06HL4z0CvFAxyc27GXpf02',
#  '07YZf4WDAMNwqr4jfgOZ8y',
#  '09Xydf4dlkr29dH99DmsvQ',
#  '0AvtzKTYleNqdJXoZasQWG',
#  '0C8ZW7ezQVs4URX5aX7Kqx',
#  '0C8kbAJOGo7CHx8jDTyTfR',
#  '0DnjaQqb436AH1idffI6CQ',
#  '0GnuCXvnvVtX5DShryuyp9',
#  '0HS00NN7MAfF59aJnfcxSO',
#  '0LyOADBjj28cbvJWTXUEGA',
#  '0MHgLfmQdutffmvWe5XBTN',
#  '0QHgL1lAIqAw0HtD7YldmP',
#  '0WleeEe3UurwlNbDGhb5Yz',
#  '0X2BH1fck6amBIoJhDVmmJ',
#  '0Y5tJX1MQlPlqiwlOH1tJY',
#  '0YrWkiT8pKvEu71t5Yllj7',
#  '0ZED1XzwlLHW4ZaG4lOT6m',
#  '0a4r2EnsevvHCukoJ1xFwJ',
#  '0cGUm45nv7Z6M6qdXYQGTX',
#  '0du5cEVh5yTK9QJze8zA0C',
#  '0ekbDNE2eOq8QiaXM34wer',
#  '0gadJ2b9A4SKsB1RFkBb66',
#  '0ghlgldX5Dd6720Q3qFyQB',
#  '0hCNtLu0JehylgoiP8L4Gh',
#  '0hEurMDQu99nJRq8pTxO14',
#  '0haZhu4fFKt0Ag94kZDiz2',
#  '0iqkVK6sTXi7DZWWOeKy8Q',
#  '0jKQrxK2zHqxyOAyIMrUQt',
#  '0jarApAsbmiCkYhz0590mE',
#  '0lslA51eKXwTUY0TSX9Emy',
#  '0n4a5imdLBN24fIrBWoqrv',
#  '0p4nmQO2msCgU4IF37Wi3j',
# ...

# %%
def get_artist(id):
    response=requests.get("https://api.spotify.com/v1/artists/{}".format(id),headers=headers)
    print(response)
    data=json.loads(response.text)
    return data

# %%
import time
artists=[]

no_of_artists = len(set(artist_ids))
artist_count = 0
for c,i in enumerate(set(artist_ids)):
    data=get_artist(i)
    artists.append(data)
    print("Track {} of {}...".format(str(c+1),no_of_artists))
    print(data["id"])
    time.sleep(1)
    
print("Done.")
# Out:
# <Response [200]>
# Track 1 of 304...
# 6ydoSd3N2mwgwBHtF6K7eX
# <Response [200]>
# Track 2 of 304...
# 5qRSs6mvI17zrkJpOHkCoM
# <Response [200]>
# Track 3 of 304...
# 09Xydf4dlkr29dH99DmsvQ
# <Response [200]>
# Track 4 of 304...
# 74KM79TiuVKeVCqs8QtB0B
# <Response [200]>
# Track 5 of 304...
# 0DnjaQqb436AH1idffI6CQ
# <Response [200]>
# Track 6 of 304...
# 6aiCKnIN68hohzU3ZzNq48
# <Response [200]>
# Track 7 of 304...
# 6k0IBR0lU42s2GYpNX7kA9
# <Response [200]>
# Track 8 of 304...
# 6USv9qhCn6zfxlBQIYJ9qs
# <Response [200]>
# Track 9 of 304...
# 4BNWanhw4AjSXjBm9L1Jzy
# <Response [200]>
# Track 10 of 304...
# 5qa31A9HySw3T7MKWI9bGg
# <Response [200]>
# Track 11 of 304...
# 7374lH6kwx9uQATYQ9H3Cp
# <Response [200]>
# Track 12 of 304...
# 4V8LLVI7PbaPR0K2TGSxFF
# <Response [200]>
# Track 13 of 304...
# 14scxEoUN7Dcx1m4EQ7oHe
# <Response [200]>
# Track 14 of 304...
# 1URnnhqYAYcrqrcwql10ft
# <Response [200]>
# Track 15 of 304...
# 5v8jlSmAQfrkTjAlpUfWtu
# <Response [200]>
# ...

# %%
artists
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ydoSd3N2mwgwBHtF6K7eX'},
#   'followers': {'href': None, 'total': 1349550},
#   'genres': ['australian pop', 'pop'],
#   'href': 'https://api.spotify.com/v1/artists/6ydoSd3N2mwgwBHtF6K7eX',
#   'id': '6ydoSd3N2mwgwBHtF6K7eX',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/1134c6cc39953feb998c83d5a7356ce6d1548a5c',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/87e98ba41d0405dd4a0a5aeca6f5f1ffea5a29bf',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/c016cd05bbb2e12a1e5d6d40e6e38f27363eb038',
#     'width': 160}],
#   'name': 'Calum Scott',
#   'popularity': 78,
#   'type': 'artist',
#   'uri': 'spotify:artist:6ydoSd3N2mwgwBHtF6K7eX'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5qRSs6mvI17zrkJpOHkCoM'},
#   'followers': {'href': None, 'total': 1907419},
#   'genres': ['k-pop', 'k-pop boy group'],
# ...

# %%
with open(file_dir+"/artists.json","w") as artists_file:
    json.dump(artists,artists_file)

# %%
def get_audio_features(id):
    response=requests.get("https://api.spotify.com/v1/audio-features/{}".format(id),headers=headers)
    print(response)
    data=json.loads(response.text)
    return data

# %%
import time
audio_features=[]

no_of_tracks = len(track_ids.unique())
track_count = 0
for c,i in enumerate(track_ids.unique()):
    data=get_audio_features(i)
    data["original_id"]=i
    audio_features.append(data)
    print("Track Audio Features {} of {}...".format(str(c+1),no_of_tracks))
    print(data["id"])
    time.sleep(1)
    
print("Done.")
# Out:
# <Response [200]>
# Track Audio Features 1 of 794...
# 2G7V7zsVDxg1yRsu7Ew9RJ
# <Response [200]>
# Track Audio Features 2 of 794...
# 7fa9MBXhVfQ8P8Df9OEbD8
# <Response [200]>
# Track Audio Features 3 of 794...
# 4u8RkgV6P4TLi89SmlUtv8
# <Response [200]>
# Track Audio Features 4 of 794...
# 4gB61mP4tNChn4LgfquMhi
# <Response [200]>
# Track Audio Features 5 of 794...
# 3WUEs51GpcvlgU7lehLgLh
# <Response [200]>
# Track Audio Features 6 of 794...
# 2BgD4nRyx9EZ5o8YEnjRSV
# <Response [200]>
# Track Audio Features 7 of 794...
# 3VQb0rq27GPX92X53Ni1Lc
# <Response [200]>
# Track Audio Features 8 of 794...
# 6SFStUDQZNaGPKWOx9ZiJB
# <Response [200]>
# Track Audio Features 9 of 794...
# 5WvAo7DNuPRmk4APhdPzi8
# <Response [200]>
# Track Audio Features 10 of 794...
# 2CWnuF7ht55Ajyeg4WPvWu
# <Response [200]>
# Track Audio Features 11 of 794...
# 0ztDBQdQmdVZvorSmIjMih
# <Response [200]>
# Track Audio Features 12 of 794...
# 3u1S1OmAUhx5DRlLrXqyp3
# <Response [200]>
# ...

# %%
with open(file_dir+"/audio_features.json","w") as audio_features_file:
    json.dump(audio_features,audio_features_file)

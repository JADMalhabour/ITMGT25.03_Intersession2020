# %%
client_id="da77ef5ab6f14964ab7936fa8b750330"
client_secret="482e21851c084e9395ce967ecacfccbd"

# %%
import requests
import json

# %%
headers = {"Authorization": "Bearer BQDjidE6kN57yxYG7JXpqQtlZAetmFqry_PwbefX_KuzHpe8IqBg9WFv6X2quJeExf2qG7xSM4oaRMVOVBbr8HbWfW6eglpbJhSpL1tNk0x4KYzeILvUNcFqeHF45cy6ZWtx35sgC73fmqeJaJFLqT7760Fs_f-9hCY3i3THjXs"}
response=requests.get("https://api.spotify.com/v1/search?q=Ed%20Sheeran&type=artist",headers=headers)

# %%
??requests.get

# %%
data = json.loads(response.text)

# %%
["{}, {}".format(d["name"],d["id"]) for d in data["artists"]["items"]]
# Out:
# ['Ed Sheeran, 6eUKZXaKkcviH0Ku9w2n3V',
#  'Ed Sheeran Band, 2czT7fmCNgyXkQAZqjYBb8',
#  'Ed Sheeran;Amy Wadge, 2Vvz9VlewaR5wMQPrEZhC2',
#  'Tribute To Ed Sheeran, 607oAIdIe0j0JCsch5U3nD']

# %%
import json

tracks = []
with open("./spotify_data/tracks.json","r") as tracks_file:
    tracks = json.load(tracks_file)

# %%
[t for t in tracks][0:10]
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1ATL5GLyefJaxhQzSPVrLX'},
#    'href': 'https://api.spotify.com/v1/albums/1ATL5GLyefJaxhQzSPVrLX',
#    'id': '1ATL5GLyefJaxhQzSPVrLX',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/542d705154be4049fc927050d006987e63739bbd',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/239ec906572231368d8ebd72614094bd3bd10b33',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/f12257240bbec6ddfa780253ac939e646eba2a36',
#      'width': 64}],
#    'name': 'Scorpion',
# ...

# %%
[{"id":t["id"],"name":t["name"], "duration_ms":t["duration_ms"], "popularity":t["popularity"]} for t in tracks]
# Out:
# [{'id': '2G7V7zsVDxg1yRsu7Ew9RJ',
#   'name': 'In My Feelings',
#   'duration_ms': 217925,
#   'popularity': 82},
#  {'id': '7fa9MBXhVfQ8P8Df9OEbD8',
#   'name': 'Girls Like You (feat. Cardi B)',
#   'duration_ms': 235545,
#   'popularity': 77},
#  {'id': '4u8RkgV6P4TLi89SmlUtv8',
#   'name': 'Mundo',
#   'duration_ms': 349713,
#   'popularity': 65},
#  {'id': '7GbAp0HKPQW7WnFJAzMoRk',
#   'name': 'Thru These Tears',
#   'duration_ms': 204515,
#   'popularity': 69},
#  {'id': '3WUEs51GpcvlgU7lehLgLh',
#   'name': 'Kathang Isip',
#   'duration_ms': 318814,
#   'popularity': 69},
#  {'id': '2BgD4nRyx9EZ5o8YEnjRSV',
#   'name': "Kung 'Di Rin Lang Ikaw",
#   'duration_ms': 267759,
#   'popularity': 71},
#  {'id': '6p6DiqAPwMX7vdrSo30wgo',
#   'name': "'Di Na Muli",
#   'duration_ms': 207018,
#   'popularity': 63},
#  {'id': '2BgEsaKNfHUdlh97KmvFyo',
#   'name': '2002',
#   'duration_ms': 186986,
#   'popularity': 81},
#  {'id': '5WvAo7DNuPRmk4APhdPzi8',
#   'name': 'No Brainer',
# ...
